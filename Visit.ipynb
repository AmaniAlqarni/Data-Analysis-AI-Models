# %% [markdown]
# # Visit

# %%
import pandas as pd
import numpy as np

# increase the number of rows & coulmns to show
pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 60)
df1 = pd.read_excel(r"C:\Users\u291963\Desktop\Ammar\Visits\20-May\Visit_Status_2.xlsx")
df2 = pd.read_excel(r"C:\Users\u291963\Desktop\Ammar\Visits\18-May\Balady violations 12-May-2025.xlsx")

# %%
print(df1.columns)
print(df2.columns)

# %%
col = ["Unnamed: 10",	"Unnamed: 11",	"Unnamed: 12"]
df2 = df2.drop(col, axis="columns")
df2

# %%
df2 = df2.merge(df1, how="left", on="رقم الزيارة")
df2

# %%
df2.to_excel(r"C:\Users\u291963\Desktop\Ammar\Visits\20-May\Baladi_2.xlsx")

# %% [markdown]
# # Visit 26 May

# %% [markdown]
# ## Draft

# %%
import pandas as pd
import numpy as np
file_path1 =r"C:\Users\u291963\Desktop\Ammar\Visits\25-May\Visits_12000_25May.xlsx"
df_visit = pd.read_excel(file_path1)
file_path2 =r"C:\Users\u291963\Desktop\Ammar\Visits\25-May\Balady_2_25May.xlsx"
df_merged = pd.read_excel(file_path2)

# %%
all_set = set(df_visit["رقم الزيارة"])
len(all_set)

# %%
Merged = set(df_merged["رقم الزيارة"])
len(Merged)

# %%
# Convert its type
DataFrame = df_visit
Start_Date_Time = "تاريخ انشاء الزيارة"	
Start_Date = "Visit_Start_Date"


DataFrame[Start_Date_Time] = pd.to_datetime(DataFrame[Start_Date_Time])
# Extract the columns

## Date
DataFrame[Start_Date] = DataFrame[Start_Date_Time].dt.date
DataFrame[Start_Date] = pd.to_datetime(DataFrame[Start_Date], format='%Y-%m-%d')

cond_1 = DataFrame["Visit_Start_Date"] <= "2025-05-11"
Temp = DataFrame[cond_1]
# check
display(Temp["Visit_Start_Date"].describe())
display(Temp.loc[:,[Start_Date_Time, Start_Date]])

# %%
Temp_trim = Temp.drop_duplicates(subset=["رقم الزيارة"])
Temp_trim.groupby("حالة الزيارة")["رقم الزيارة"].agg("count")

# %%
all_set = set(Temp["رقم الزيارة"])
len(all_set)

# %%
Merged = set(df_merged["رقم الزيارة"])
len(Merged)

# %%
1364 - 992

# %%
372/1364 * 100

# %% [markdown]
# ## Visit to_compalint 19 May (Full)

# %%
import pandas as pd
import numpy as np
file_path =r"C:\Users\u291963\Desktop\Ammar\Visits\Visits_12000_25May.xlsx"
df_visit12 = pd.read_excel(file_path)
display(df_visit12.head(2))
display(df_visit12.tail(2))

# %%
# Convert its type
DataFrame = df_visit12
Start_Date_Time = "تاريخ انشاء الزيارة"	
Start_Date = "Visit_Start_Date"
Start_Time = "Visit_Start_Time"

DataFrame[Start_Date_Time] = pd.to_datetime(DataFrame[Start_Date_Time])
# Extract the columns

## Date
DataFrame[Start_Date] = DataFrame[Start_Date_Time].dt.date
DataFrame[Start_Date] = pd.to_datetime(DataFrame[Start_Date], format='%Y-%m-%d')

## Time
DataFrame[Start_Time]  = DataFrame[Start_Date_Time].dt.time
DataFrame[Start_Time]  = pd.to_datetime(DataFrame[Start_Time] ,format='%H:%M:%S').dt.time

# check
DataFrame.loc[:,[Start_Date_Time, Start_Date, Start_Time]]

# %%
# Convert its type
DataFrame = df_visit12
End_Date_Time = "تاريخ اعتماد المخالفة"	
End_Date = "Complaint_Date"
End_Time = "Complaint_Time"

DataFrame[End_Date_Time] = pd.to_datetime(DataFrame[End_Date_Time])
# Extract the columns

## Date
DataFrame[End_Date] = DataFrame[End_Date_Time].dt.date
DataFrame[End_Date] = pd.to_datetime(DataFrame[End_Date], format='%Y-%m-%d')

## Time
DataFrame[End_Time]  = DataFrame[End_Date_Time].dt.time
DataFrame[End_Time]  = pd.to_datetime(DataFrame[End_Time] ,format='%H:%M:%S').dt.time

# check
DataFrame.loc[:,[End_Date_Time, End_Date, End_Time]]

# %%
Duration = "Visit_Complaint_Duration"

DataFrame[Duration] = DataFrame[End_Date_Time] - DataFrame[Start_Date_Time]

DataFrame.loc[:,[End_Date_Time,Start_Date_Time,Duration]]

# %%
DataFrame.groupby("حالة الزيارة")[[Duration]].agg(["mean", "count"])

# %% [markdown]
# ## Visit to_compalint 11 May

# %%
import pandas as pd
import numpy as np
file_path =r"C:\Users\u291963\Desktop\Ammar\Visits & Complaints\25-May\Visits_12000_25May.xlsx"
df_visit12 = pd.read_excel(file_path)
display(df_visit12.head(2))
display(df_visit12.tail(2))

# %%
# Convert its type
DataFrame = df_visit12
Start_Date_Time = "تاريخ انشاء الزيارة"	
Start_Date = "Visit_Start_Date"
Start_Time = "Visit_Start_Time"

DataFrame[Start_Date_Time] = pd.to_datetime(DataFrame[Start_Date_Time])
# Extract the columns

## Date
DataFrame[Start_Date] = DataFrame[Start_Date_Time].dt.date
DataFrame[Start_Date] = pd.to_datetime(DataFrame[Start_Date], format='%Y-%m-%d')

## Time
DataFrame[Start_Time]  = DataFrame[Start_Date_Time].dt.time
DataFrame[Start_Time]  = pd.to_datetime(DataFrame[Start_Time] ,format='%H:%M:%S').dt.time

# check
DataFrame.loc[:,[Start_Date_Time, Start_Date, Start_Time]]

# %%
cond_1 = DataFrame["Visit_Start_Date"] <= "2025-05-11"
Temp = DataFrame[cond_1]
Temp["Visit_Start_Date"].describe()

# %%
Temp.sort_values("Visit_Start_Date").tail(2)

# %%
# Convert its type
End_Date_Time = "تاريخ اعتماد المخالفة"	
End_Date = "Complaint_Date"
End_Time = "Complaint_Time"
DataFrame = Temp

DataFrame[End_Date_Time] = pd.to_datetime(DataFrame[End_Date_Time])
# Extract the columns

## Date
DataFrame[End_Date] = DataFrame[End_Date_Time].dt.date
DataFrame[End_Date] = pd.to_datetime(DataFrame[End_Date], format='%Y-%m-%d')

## Time
DataFrame[End_Time]  = DataFrame[End_Date_Time].dt.time
DataFrame[End_Time]  = pd.to_datetime(DataFrame[End_Time] ,format='%H:%M:%S').dt.time

# check
DataFrame.loc[:,[End_Date_Time, End_Date, End_Time]]

# %%
Duration = "Visit_Complaint_Duration"

DataFrame[Duration] = DataFrame[End_Date_Time] - DataFrame[Start_Date_Time]

DataFrame.loc[:,[End_Date_Time,Start_Date_Time,Duration]]

# %%
DataFrame.groupby("حالة الزيارة", dropna=False)[[Duration]].agg(["mean", "count"])

# %%
DataFrame["حالة الزيارة"].value_counts().reset_index()

# %% [markdown]
# ## Visit_Duration 19 May (Full)

# %%
import pandas as pd
import numpy as np
file_path =r"C:\Users\u291963\Desktop\Ammar\Visits\Visits_12000_25May.xlsx"
df_visit12 = pd.read_excel(file_path)
display(df_visit12.head(2))
display(df_visit12.tail(2))

# %%
# Convert its type
DataFrame = df_visit12
Start_Date_Time = "تاريخ انشاء الزيارة"	
Start_Date = "Visit_Start_Date"
Start_Time = "Visit_Start_Time"

DataFrame[Start_Date_Time] = pd.to_datetime(DataFrame[Start_Date_Time])
# Extract the columns

## Date
DataFrame[Start_Date] = DataFrame[Start_Date_Time].dt.date
DataFrame[Start_Date] = pd.to_datetime(DataFrame[Start_Date], format='%Y-%m-%d')

## Time
DataFrame[Start_Time]  = DataFrame[Start_Date_Time].dt.time
DataFrame[Start_Time]  = pd.to_datetime(DataFrame[Start_Time] ,format='%H:%M:%S').dt.time

# check
DataFrame.loc[:,[Start_Date_Time, Start_Date, Start_Time]]

# %%
# Convert its type
DataFrame = df_visit12
End_Date_Time = "تاريخ انهاء الزيارة"	
End_Date = "Visit_End_Date"
End_Time = "Visit_End_Time"

DataFrame[End_Date_Time] = pd.to_datetime(DataFrame[End_Date_Time])
# Extract the columns

## Date
DataFrame[End_Date] = DataFrame[End_Date_Time].dt.date
DataFrame[End_Date] = pd.to_datetime(DataFrame[End_Date], format='%Y-%m-%d')

## Time
DataFrame[End_Time]  = DataFrame[End_Date_Time].dt.time
DataFrame[End_Time]  = pd.to_datetime(DataFrame[End_Time] ,format='%H:%M:%S').dt.time

# check
DataFrame.loc[:,[End_Date_Time, End_Date, End_Time]]

# %%
Duration = "Visit_Duration"

DataFrame[Duration] = DataFrame[End_Date_Time] - DataFrame[Start_Date_Time]

DataFrame.loc[:,[End_Date_Time,Start_Date_Time,Duration]]

# %%
DataFrame.groupby("حالة الزيارة")[[Duration]].agg(["mean", "count"])

# %% [markdown]
# ## Visit_Duration 11 May

# %%
import pandas as pd
import numpy as np
file_path =r"C:\Users\u291963\Desktop\Ammar\Visits\Visits_12000_25May.xlsx"
df_visit12 = pd.read_excel(file_path)
display(df_visit12.head(2))
display(df_visit12.tail(2))

# %%
# Convert its type
DataFrame = df_visit12
Start_Date_Time = "تاريخ انشاء الزيارة"	
Start_Date = "Visit_Start_Date"
Start_Time = "Visit_Start_Time"

DataFrame[Start_Date_Time] = pd.to_datetime(DataFrame[Start_Date_Time])
# Extract the columns

## Date
DataFrame[Start_Date] = DataFrame[Start_Date_Time].dt.date
DataFrame[Start_Date] = pd.to_datetime(DataFrame[Start_Date], format='%Y-%m-%d')

## Time
DataFrame[Start_Time]  = DataFrame[Start_Date_Time].dt.time
DataFrame[Start_Time]  = pd.to_datetime(DataFrame[Start_Time] ,format='%H:%M:%S').dt.time

# check
DataFrame.loc[:,[Start_Date_Time, Start_Date, Start_Time]]

# %%
cond_1 = DataFrame["Visit_Start_Date"] <= "2025-05-11"
Temp = DataFrame[cond_1]
Temp["Visit_Start_Date"].describe()

# %%
# Convert its type
DataFrame = Temp
End_Date_Time = "تاريخ انهاء الزيارة"	
End_Date = "Visit_End_Date"
End_Time = "Visit_End_Time"

DataFrame[End_Date_Time] = pd.to_datetime(DataFrame[End_Date_Time])
# Extract the columns

## Date
DataFrame[End_Date] = DataFrame[End_Date_Time].dt.date
DataFrame[End_Date] = pd.to_datetime(DataFrame[End_Date], format='%Y-%m-%d')

## Time
DataFrame[End_Time]  = DataFrame[End_Date_Time].dt.time
DataFrame[End_Time]  = pd.to_datetime(DataFrame[End_Time] ,format='%H:%M:%S').dt.time

# check
DataFrame.loc[:,[End_Date_Time, End_Date, End_Time]]

# %%
Duration = "Visit_Duration"

DataFrame[Duration] = DataFrame[End_Date_Time] - DataFrame[Start_Date_Time]

DataFrame.loc[:,[End_Date_Time,Start_Date_Time,Duration]]

# %%
DataFrame.groupby("حالة الزيارة")[[Duration]].agg(["mean", "count"])

# %%
DataFrame["حالة الزيارة"].value_counts().reset_index()

# %% [markdown]
# ## Baladi

# %%
import pandas as pd
import numpy as np
file_path =r"C:\Users\u291963\Desktop\Ammar\Visits\20-May\Balady_2.xlsx"
df_Complaint = pd.read_excel(file_path)
df_Complaint

# %%
# Convert its type
DateFrame = df_Complaint
Date_Time = "تاريخ الاستلام من بلدي"
Date = "Receive_Date"
Time = "Receive_Time"

DateFrame[Date_Time] = pd.to_datetime(DateFrame[Date_Time])
# Extract the columns

## Date
DateFrame[Date] = DateFrame[Date_Time].dt.date
DateFrame[Date] = pd.to_datetime(DateFrame[Date], format='%Y-%m-%d')

## Time
DateFrame[Time]  = DateFrame[Date_Time].dt.time
DateFrame[Time]  = pd.to_datetime(DateFrame[Time] ,format='%H:%M:%S').dt.time

# check
DateFrame.loc[:,[Date_Time, Date, Time]]

# %%
DateFrame.describe()

# %% [markdown]
# ## Baladi 25 May

# %%
import pandas as pd
import numpy as np
file_path =r"C:\Users\u291963\Desktop\Ammar\Visits & Complaints\25-May\Balady_2_25May.xlsx"
df_Merged = pd.read_excel(file_path)
df_Merged
# Out:
#       Unnamed: 0 رقم الزيارة  التكرار  معرف المخالفة في النظام  \
# 0              0   SWA-13013      NaN                     1084
# 1              1   SWA-13036      NaN                     1085
# 2              2    SWA-9055      NaN                     1086
# 3              3   SWA-11018      NaN                     1087
# 4              4    SWA-9029      NaN                     1088
# ...          ...         ...      ...                      ...
# 1022        1022   SWA-43274      NaN                     2717
# 1023        1023   SWA-50143      NaN                     2718
# 1024        1024   SWA-50142      NaN                     2719
# 1025        1025   SWA-48123      NaN                     2720
# 1026        1026   SWA-44064      NaN                     2721
#
#                      حالة المخالفة تاريخ الاستلام من بلدي  \
# 0                    جديد من ممتثل    2025-02-06 18:03:00
# 1     تم إرجاعه من قبل أمين اللجنة    2025-02-06 18:06:00
# ...

# %%
df_Merged.columns
# Out:
# Index(['Unnamed: 0', 'رقم الزيارة', 'التكرار', 'معرف المخالفة في النظام',
#        'حالة المخالفة', 'تاريخ الاستلام من بلدي', 'تاريخ الارسال للمخالف',
#        'استلام البلاغ --> إرسال للمخالف',
#        'تاريخ رد المخالف والوصول الى امانة اللجنة',
#        'إرسال للمخالف --> رد المخالف', 'تاريخ الارسال الى اللجنة',
#        'رد المخالف --> إرسال للجنة', 'تاريخ الارسال الى معالي رئيس الهيئة',
#        'إرسال للجنة --> إرسال للمعالي', 'تاريخ قرار معالي رئيس الهيئة',
#        'إرسال للمعالي --> صدور قرار المعالي',
#        'رقم الهوية / الاقامة / السجل التجاري    للمخالف', 'معرف المخالفة',
#        'نوع الزيارة', 'حالة الزيارة', 'تاريخ انشاء الزيارة',
#        'تاريخ انهاء الزيارة', 'الاحداثيات', 'المنطقة', 'المحافظة',
#        'هوية المراقب', 'اسم المراقب', 'هاتف المراقب', 'ايميل المراقب',
#        'القطاع', 'رقم الرخصة', 'اسم المنشاة', 'مرحلة الى', 'التصنيف الرئيسي',
#        'التصنيف الفرعي', 'قرار مدير الرقابة', 'سبب القرار', 'معرف العقار',
# ...

# %% [markdown]
# ### Convert into Date Type

# %%
# Convert its type
DataFrame = df_Merged
Start_Date_Time_1 = "تاريخ الاستلام من بلدي"

DataFrame[Start_Date_Time_1] = pd.to_datetime(DataFrame[Start_Date_Time_1])
#--------------------------------------------------------------------------
# Convert its type
DataFrame = df_Merged
Start_Date_Time_2 = "تاريخ الارسال للمخالف"

DataFrame[Start_Date_Time_2] = pd.to_datetime(DataFrame[Start_Date_Time_2])
#--------------------------------------------------------------------------
# Convert its type
DataFrame = df_Merged
Start_Date_Time_3 = "تاريخ رد المخالف والوصول الى امانة اللجنة"

DataFrame[Start_Date_Time_3] = pd.to_datetime(DataFrame[Start_Date_Time_3])
#--------------------------------------------------------------------------
# Convert its type
DataFrame = df_Merged
Start_Date_Time_4 = "تاريخ الارسال الى اللجنة"

DataFrame[Start_Date_Time_4] = pd.to_datetime(DataFrame[Start_Date_Time_4])
#--------------------------------------------------------------------------
# Convert its type
DataFrame = df_Merged
Start_Date_Time_5 = "تاريخ الارسال الى معالي رئيس الهيئة"

DataFrame[Start_Date_Time_5] = pd.to_datetime(DataFrame[Start_Date_Time_5])
#--------------------------------------------------------------------------
# Convert its type
DataFrame = df_Merged
Start_Date_Time_6 = "تاريخ قرار معالي رئيس الهيئة"

DataFrame[Start_Date_Time_6] = pd.to_datetime(DataFrame[Start_Date_Time_6])
#--------------------------------------------------------------------------

# %% [markdown]
# ### Create Duration columns

# %%
Duration = "1_2"
DataFrame[Duration] = DataFrame[Start_Date_Time_2] - DataFrame[Start_Date_Time_1]
DataFrame.loc[:,[Start_Date_Time_2,Start_Date_Time_1,Duration]]
#------------------------------------------------------------
Duration = "2_3"
DataFrame[Duration] = DataFrame[Start_Date_Time_3] - DataFrame[Start_Date_Time_2]
DataFrame.loc[:,[Start_Date_Time_3,Start_Date_Time_2,Duration]]
#------------------------------------------------------------
Duration = "3_4"
DataFrame[Duration] = DataFrame[Start_Date_Time_4] - DataFrame[Start_Date_Time_3]
DataFrame.loc[:,[Start_Date_Time_4,Start_Date_Time_3,Duration]]
#------------------------------------------------------------
Duration = "4_5"
DataFrame[Duration] = DataFrame[Start_Date_Time_5] - DataFrame[Start_Date_Time_4]
DataFrame.loc[:,[Start_Date_Time_5,Start_Date_Time_4,Duration]]
#------------------------------------------------------------
Duration = "5_6"
DataFrame[Duration] = DataFrame[Start_Date_Time_6] - DataFrame[Start_Date_Time_5]
DataFrame.loc[:,[Start_Date_Time_6,Start_Date_Time_5,Duration]]
#------------------------------------------------------------
# Out:
#      تاريخ قرار معالي رئيس الهيئة تاريخ الارسال الى معالي رئيس الهيئة  \
# 0                             NaT                                 NaT
# 1                             NaT                                 NaT
# 2             2025-03-02 01:07:00                 2025-02-25 14:11:00
# 3             2025-03-02 01:07:00                 2025-02-25 14:09:00
# 4             2025-03-02 01:06:00                 2025-02-25 13:55:00
# ...                           ...                                 ...
# 1022                          NaT                                 NaT
# 1023                          NaT                                 NaT
# 1024                          NaT                                 NaT
# 1025                          NaT                                 NaT
# 1026                          NaT                                 NaT
#
#                  5_6
# 0                NaT
# 1                NaT
# 2    4 days 10:56:00
# 3    4 days 10:58:00
# ...

# %%
DataFrame.groupby("حالة المخالفة")[["1_2"]].agg(["mean", "count"])
# Out:
#                                                     1_2
#                                                    mean count
# حالة المخالفة
# تم إرجاعه لإعادة التصويت               19 days 14:50:00     4
# تم إرجاعه من قبل أمين اللجنة  7 days 09:23:07.826086956    23
# جديد من ممتثل                                       NaT     0
# في عملية التصويت             10 days 07:25:07.096774193    93
# قيد مراجعة اللجنة             9 days 03:22:16.363636363    55
# قيد مراجعة المستخدم           0 days 18:55:39.574468085    47
# قيد مراجعة رئيس الهيئة        0 days 19:35:33.333333333     9
# مكتمل                         4 days 09:05:02.857142857    21

# %%
DataFrame.groupby("حالة المخالفة")[["2_3"]].agg(["mean", "count"])

# %%
DataFrame.groupby("حالة المخالفة")[["3_4"]].agg(["mean", "count"])

# %%
DataFrame.groupby("حالة المخالفة")[["4_5"]].agg(["mean", "count"])

# %%
DataFrame.groupby("حالة المخالفة")[["5_6"]].agg(["mean", "count"])

# %%
DataFrame.describe().T[["mean"]]

# %% [markdown]
# # Visits 29 June Durations

# %%
import pandas as pd
import numpy as np
file_path =r"C:\Users\u291963\Desktop\Ammar\Visits & Complaints\29-June\Visits_29_June.xlsx"
df_visit12 = pd.read_excel(file_path)
display(df_visit12.head(2))
display(df_visit12.tail(2))

# %%
Full = df_visit12.shape[0]
clean= df_visit12.drop_duplicates(subset="رقم الزيارة").shape[0]
duplicated = Full - clean
print(duplicated)
print("check", df_visit12["رقم الزيارة"].duplicated().sum())

# %%
Full = df_visit12.shape[0]
clean= df_visit12.drop_duplicates().shape[0]
duplicated = Full - clean
print(duplicated)
print("check", DataFrame["رقم الزيارة"].duplicated().sum())

# %%
# Convert its type
DataFrame = df_visit12
Start_Date_Time = "تاريخ انشاء الزيارة"	
Start_Date = "Visit_Start_Date"
Start_Time = "Visit_Start_Time"

DataFrame[Start_Date_Time] = pd.to_datetime(DataFrame[Start_Date_Time])
# Extract the columns

## Date
DataFrame[Start_Date] = DataFrame[Start_Date_Time].dt.date
DataFrame[Start_Date] = pd.to_datetime(DataFrame[Start_Date], format='%Y-%m-%d')

## Time
DataFrame[Start_Time]  = DataFrame[Start_Date_Time].dt.time
DataFrame[Start_Time]  = pd.to_datetime(DataFrame[Start_Time] ,format='%H:%M:%S').dt.time

# check
DataFrame.loc[:,[Start_Date_Time, Start_Date, Start_Time]]

# %%
DataFrame.sort_values(["Visit_Start_Date"], ascending=False)

# %%
# Convert its type
DataFrame = df_visit12
End_Date_Time = "تاريخ انهاء الزيارة"	
End_Date = "Visit_End_Date"
End_Time = "Visit_End_Time"

DataFrame[End_Date_Time] = pd.to_datetime(DataFrame[End_Date_Time])
# Extract the columns

## Date
DataFrame[End_Date] = DataFrame[End_Date_Time].dt.date
DataFrame[End_Date] = pd.to_datetime(DataFrame[End_Date], format='%Y-%m-%d')

## Time
DataFrame[End_Time]  = DataFrame[End_Date_Time].dt.time
DataFrame[End_Time]  = pd.to_datetime(DataFrame[End_Time] ,format='%H:%M:%S').dt.time

# check
DataFrame.loc[:,[End_Date_Time, End_Date, End_Time]]

# %%
DataFrame.sort_values(["Visit_End_Date"], ascending=False)

# %%
Duration = "Visit_Duration"

DataFrame[Duration] = DataFrame[End_Date_Time] - DataFrame[Start_Date_Time]

DataFrame.loc[:,[End_Date_Time,Start_Date_Time,Duration]]

# %%
DataFrame.sort_values("Visit_Duration", ascending=False).head(20)

# %%
DataFrame[DataFrame["Visit_Duration"] > "75 days"][[""]]

# %%
DataFrame.groupby("حالة الزيارة", dropna=False)[[Duration]].agg(["mean", "count"])

# %%
# Assuming your DataFrame is named 'df'
counts = DataFrame['رقم الزيارة'].value_counts()
duplicated_counts = counts[counts > 1]

# duplicated_counts now contains the counts of duplicated values in 'col1'
# To display it as a DataFrame:
duplicated_df = duplicated_counts.reset_index()
duplicated_df.columns = ['رقم الزيارة', 'count']
display(duplicated_df)
display(duplicated_df["count"].sum())

# %%
# duplicated_df.to_excel(r"C:\Users\u291963\Desktop\Ammar\Visits & Complaints\29-June\Dupliacted_visits_29June.xlsx")

# %% [markdown]
# # CRM Baladi (01_July)
# this before visit (initiator to visit)

# %%
df_CRM = pd.read_excel(r"C:\Users\u291963\Desktop\Ammar\Visits & Complaints\01_July\CRM Baladi_01_June.xlsx")
print(df_CRM.shape[0])
df_CRM_fixed = df_CRM.drop(["المحافظة"], axis="columns")
display(df_CRM.shape)
display(df_CRM_fixed.shape)

# %%
df_CRM_fixed = df_CRM_fixed.drop_duplicates()
display(df_CRM_fixed.shape)

# %%
df_CRM_fixed.columns

# %%
# Convert its type
DataFrame = df_CRM_fixed
Start_Date_Time = "تاريخ تقديم البلاغ"	
Start_Date = "Complaint_Start_Date"
Start_Time = "Complaint_Start_Time"

DataFrame[Start_Date_Time] = pd.to_datetime(DataFrame[Start_Date_Time])
# Extract the columns

## Date
DataFrame[Start_Date] = DataFrame[Start_Date_Time].dt.date
DataFrame[Start_Date] = pd.to_datetime(DataFrame[Start_Date], format='%Y-%m-%d')

## Time
DataFrame[Start_Time]  = DataFrame[Start_Date_Time].dt.time
DataFrame[Start_Time]  = pd.to_datetime(DataFrame[Start_Time] ,format='%H:%M:%S').dt.time

# check
DataFrame.loc[:,[Start_Date_Time, Start_Date, Start_Time]]

# %%
df_CRM_fixed

# %%
df_eastern = df_CRM[df_CRM["المنطقة"] == "الشرقية"]
df_eastern

# %%
df_Riadh= df_CRM[df_CRM["المنطقة"] == "الرياض"]
# Assuming your DataFrame is named 'df'
counts = df_Riadh['رقم الزيارة'].value_counts()
duplicated_counts = counts[counts > 1]

# duplicated_counts now contains the counts of duplicated values in 'col1'
# To display it as a DataFrame:
duplicated_df = duplicated_counts.reset_index()
duplicated_df.columns = ['رقم الزيارة', 'count']
display(duplicated_df.sort_values("count"))

# %%
# Assuming your DataFrame is named 'df'
counts = df_eastern['رقم الزيارة'].value_counts()
duplicated_counts = counts[counts > 1]

# duplicated_counts now contains the counts of duplicated values in 'col1'
# To display it as a DataFrame:
duplicated_df = duplicated_counts.reset_index()
duplicated_df.columns = ['رقم الزيارة', 'count']
print(duplicated_df)

# %% [markdown]
# # Merge Complaint & Visit
# visit 29_June, Complaint01_Jule

# %%
import pandas as pd
import numpy as np
file_path =r"C:\Users\u291963\Desktop\Ammar\Visits & Complaints\29-June\Visits_29_June.xlsx"
df_visit = pd.read_excel(file_path)
display(df_visit.shape)

# %%
df_visit.columns

# %%
df_Complaint = pd.read_excel(r"C:\Users\u291963\Desktop\Ammar\Visits & Complaints\01_July\CRM Baladi_01_June.xlsx")
df_Complaint = df_Complaint.drop(["المحافظة"], axis="columns")
df_Complaint = df_Complaint.drop_duplicates()
display(df_Complaint.shape)

# %%
df_Complaint.columns

# %%
df_merged = df_visit.merge(df_Complaint, how="inner", on="رقم الزيارة",suffixes=("_visit", "_Complaint"))
print("Visit Shape: ",df_visit.shape)
print("Complaint Shape: ",df_Complaint.shape)
print("Merged Shape: ",df_merged.shape)

# %%
df_merged

# %%
df_merged_noID = df_merged.drop("هوية المفتش", axis="columns")
df_merged_noID

# %%
# Convert its type
DataFrame = df_merged_noID
Start_Date_Time = "تاريخ انشاء الزيارة"	
Start_Date = "Visit_Start_Date"
Start_Time = "Visit_Start_Time"

DataFrame[Start_Date_Time] = pd.to_datetime(DataFrame[Start_Date_Time])
# Extract the columns

## Date
DataFrame[Start_Date] = DataFrame[Start_Date_Time].dt.date
DataFrame[Start_Date] = pd.to_datetime(DataFrame[Start_Date], format='%Y-%m-%d')

## Time
DataFrame[Start_Time]  = DataFrame[Start_Date_Time].dt.time
DataFrame[Start_Time]  = pd.to_datetime(DataFrame[Start_Time] ,format='%H:%M:%S').dt.time

# check
DataFrame.loc[:,[Start_Date_Time, Start_Date, Start_Time]]

# %%
# Convert its type
DataFrame = df_merged_noID
End_Date_Time = "تاريخ انهاء الزيارة"	
End_Date = "Visit_End_Date"
End_Time = "Visit_End_Time"

DataFrame[End_Date_Time] = pd.to_datetime(DataFrame[End_Date_Time])
# Extract the columns

## Date
DataFrame[End_Date] = DataFrame[End_Date_Time].dt.date
DataFrame[End_Date] = pd.to_datetime(DataFrame[End_Date], format='%Y-%m-%d')

## Time
DataFrame[End_Time]  = DataFrame[End_Date_Time].dt.time
DataFrame[End_Time]  = pd.to_datetime(DataFrame[End_Time] ,format='%H:%M:%S').dt.time

# check
DataFrame.loc[:,[End_Date_Time, End_Date, End_Time]]

# %%
Duration = "Visit_Duration"

DataFrame[Duration] = DataFrame[End_Date_Time] - DataFrame[Start_Date_Time]

DataFrame.loc[:,[End_Date_Time,Start_Date_Time,Duration]]

# %%
df_merged_noID

# %%
print(df_merged_noID.shape)
df_merged_noID["Visit_Start_Date"] = pd.to_datetime(df_merged_noID["Visit_Start_Date"])
cond_1 = df_merged_noID["Visit_Start_Date"] >= "2025-06-13"
cond_2 = df_merged_noID["Visit_Start_Date"] <= "2025-06-26"

df_CRM_fixed_13_26June = df_merged_noID[cond_1 & cond_2]
print(df_CRM_fixed_13_26June.shape)

# %%
# df_merged_noID.to_excel(r"C:\Users\u291963\Desktop\Ammar\Visits & Complaints\01_July\Merged_Complaint_Visits.xlsx")

# %% [markdown]
# # Visit for Fact Report
# using 29_June file

# %%
import pandas as pd
import numpy as np
file_path =r"C:\Users\u291963\Desktop\Ammar\Visits & Complaints\29-June\Visits_29_June.xlsx"
df_visit = pd.read_excel(file_path)
df_visit.sample(3)
# Out:
#       رقم الزيارة معرف المخالفة       نوع الزيارة             حالة الزيارة  \
# 8379    SWA-38455     V-3779856  زيارة غير مجدولة  تم ارسالها للنظر والفصل
# 1663    SWA-44071     V-3852405  زيارة غير مجدولة     لا يوجد بيانات مخالف
# 12963   SWA-32941     V-3845050  زيارة غير مجدولة  تم ارسالها للنظر والفصل
#
#        تاريخ انشاء الزيارة  تاريخ انهاء الزيارة  \
# 8379   4/28/25 11:41:04 AM  4/28/25 12:15:06 PM
# 1663     5/8/25 2:25:39 PM    5/8/25 2:47:12 PM
# 12963   4/30/25 9:19:55 AM    5/7/25 4:57:00 PM
#
#                                  الاحداثيات  المنطقة        المحافظة  \
# 8379    24.878014490009647,46.8300523416156   الرياض    مدينة الرياض
# 1663                  26.5124541,50.0290365  الشرقية  محافظة البيضاء
# 12963  25.374286455772847,49.58257043415194  الشرقية  محافظة الإحساء
#
#        هوية المراقب  ...    رقم الرخصة                           اسم المنشاة  \
# 8379     1024408195  ...  لا يوجد رخصة  مؤسسة نايف عيد عواض المطيري التجارية
# ...

# %%
# Convert its type
DataFrame = df_visit
Start_Date_Time = "تاريخ انشاء الزيارة"	
Start_Date = "Visit_Start_Date"
Start_Time = "Visit_Start_Time"

DataFrame[Start_Date_Time] = pd.to_datetime(DataFrame[Start_Date_Time])
# Extract the columns

## Date
DataFrame[Start_Date] = DataFrame[Start_Date_Time].dt.date
DataFrame[Start_Date] = pd.to_datetime(DataFrame[Start_Date], format='%Y-%m-%d')

## Time
DataFrame[Start_Time]  = DataFrame[Start_Date_Time].dt.time
DataFrame[Start_Time]  = pd.to_datetime(DataFrame[Start_Time] ,format='%H:%M:%S').dt.time

# check
DataFrame.loc[:,[Start_Date_Time, Start_Date, Start_Time]]

#--------------------------------------------------------------


# Convert its type
End_Date_Time = "تاريخ انهاء الزيارة"	
End_Date = "Visit_End_Date"
End_Time = "Visit_End_Time"

DataFrame[End_Date_Time] = pd.to_datetime(DataFrame[End_Date_Time])
# Extract the columns

## Date
DataFrame[End_Date] = DataFrame[End_Date_Time].dt.date
DataFrame[End_Date] = pd.to_datetime(DataFrame[End_Date], format='%Y-%m-%d')

## Time
DataFrame[End_Time]  = DataFrame[End_Date_Time].dt.time
DataFrame[End_Time]  = pd.to_datetime(DataFrame[End_Time] ,format='%H:%M:%S').dt.time

# check
DataFrame.loc[:,[End_Date_Time, End_Date, End_Time]]

# ---------------------------------------------

Duration = "Visit_Duration"

DataFrame[Duration] = DataFrame[End_Date_Time] - DataFrame[Start_Date_Time]

DataFrame.loc[:,[End_Date_Time,Start_Date_Time,Duration]]
# Out:
# C:\Users\u291963\AppData\Local\Temp\ipykernel_6148\3018196562.py:7: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   DataFrame[Start_Date_Time] = pd.to_datetime(DataFrame[Start_Date_Time])
# C:\Users\u291963\AppData\Local\Temp\ipykernel_6148\3018196562.py:29: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   DataFrame[End_Date_Time] = pd.to_datetime(DataFrame[End_Date_Time])
#       تاريخ انهاء الزيارة تاريخ انشاء الزيارة  Visit_Duration
# 0     2025-01-10 19:01:36 2025-01-09 10:12:17 1 days 08:49:19
# 1     2025-01-27 12:09:53 2025-01-27 12:02:21 0 days 00:07:32
# 2     2025-03-11 12:26:44 2025-03-11 12:15:25 0 days 00:11:19
# 3     2025-03-04 15:55:20 2025-03-04 15:46:53 0 days 00:08:27
# ...

# %%
print(df_visit["Visit_Start_Date"].min())
print(df_visit["Visit_Start_Date"].max())
# Out:
# 2025-01-01 00:00:00
# 2025-06-28 00:00:00

# %%
df_visit["القطاع"].value_counts(dropna=False).reset_index()
# Out:
#                 القطاع  count
# 0                  NaN  10532
# 1  شركة المياه الوطنية   8805
# 2             الامانات    149

# %%
print(df_visit.shape)
df_visit_truncated = df_visit.drop_duplicates(subset=["رقم الزيارة", "معرف المخالفة"])
print(df_visit_truncated.shape)
# Out:
# (19486, 29)
# (19428, 29)

# %%
display(df_visit_truncated.value_counts("نوع الزيارة",dropna=False).reset_index())
display(df_visit_truncated.value_counts("نوع الزيارة",dropna=False).reset_index()["count"].sum())
# Out:
#         نوع الزيارة  count
# 0  زيارة غير مجدولة  17041
# 1    بلاغ مواطن 940   2387
# np.int64(19428)

# %%
df_visit_truncated["التصنيف الفرعي"].value_counts().reset_index()
# Out:
#                               التصنيف الفرعي  count
# 0                               تسرب من عقار   8631
# 1                             تسرب شبكة مياه   7381
# 2                                الصرف الصحي   2418
# 3  مزاولة العمل بالأشياب دون الحصول على رخصة    276
# 4                      تسرب مياه من الصهاريج    175
# 5                         مخالفات المرخص لهم     17

# %%
# How many of the 19428 visits is from CRM Baladi (It should be same as بلاغ مواطن 940	)
df_merged = df_visit_truncated.merge(df_Complaint, how="inner", on="رقم الزيارة",suffixes=("_visit", "_Complaint"))
print("Visit Shape: ",df_visit_truncated.shape)
print("Complaint Shape: ",df_Complaint.shape)
print("Merged Shape: ",df_merged.shape)

# %%
cond1 = df_visit_truncated["Visit_Start_Date"] >="2025-01-01"
cond2 = df_visit_truncated["Visit_Start_Date"] <"2025-01-03"
cond3 = df_visit_truncated["Visit_Start_Date"] >="2025-06-27"
print(df_visit_truncated[cond1 & cond2].shape[0])
print(df_visit_truncated[cond3].shape[0])

# %% [markdown]
# ## Visit2

# %%
import pandas as pd

# Assuming your DataFrame is named df_visit_truncated and the date column is "Visit_Start_Date"

# Convert 'Visit_Start_Date' to datetime objects
df_visit_truncated['Visit_Start_Date'] = pd.to_datetime(df_visit_truncated['Visit_Start_Date'])

# Define the end date of your main range
end_date = pd.to_datetime('2025-06-26')

# Define the start date of your main range
start_date = pd.to_datetime('2025-06-20')

# Calculate visits in the main date range (2025-06-20 to 2025-06-26)
main_range_visits = df_visit_truncated[(df_visit_truncated['Visit_Start_Date'] >= start_date) & (df_visit_truncated['Visit_Start_Date'] <= end_date)].shape[0]

print(f"Visits from 2025-06-20 to 2025-06-26: {main_range_visits}")

# Calculate visits for each preceding week
current_start = start_date - pd.Timedelta(days=7)
current_end = start_date - pd.Timedelta(days=1)

while current_start >= df_visit_truncated['Visit_Start_Date'].min():  # Assuming you want to stop at the earliest date in your data
    weekly_visits = df_visit_truncated[(df_visit_truncated['Visit_Start_Date'] >= current_start) & (df_visit_truncated['Visit_Start_Date'] <= current_end)].shape[0]
    print(f"Visits from {current_start.strftime('%Y-%m-%d')} to {current_end.strftime('%Y-%m-%d')}: {weekly_visits}")
    
    # Move to the previous week
    current_end = current_start - pd.Timedelta(days=1)
    current_start = current_start - pd.Timedelta(days=7)

# %%
#Check

# First_Week
cond1 = df_visit_truncated["Visit_Start_Date"] <="2025-06-26"
cond2 = df_visit_truncated["Visit_Start_Date"] >="2025-06-20"
print("First_Week", df_visit_truncated[cond1 & cond2].shape[0])

#############
# -1_Week
cond1 = df_visit_truncated["Visit_Start_Date"] <="2025-06-19"
cond2 = df_visit_truncated["Visit_Start_Date"] >="2025-06-13"
print("-1_Week", df_visit_truncated[cond1 & cond2].shape[0])

#############
# -2_Week
cond1 = df_visit_truncated["Visit_Start_Date"] <="2025-06-12"
cond2 = df_visit_truncated["Visit_Start_Date"] >="2025-06-06"
print("-2_Week", df_visit_truncated[cond1 & cond2].shape[0])

# %%
# 13 t0 26 June
cond1 = df_visit_truncated["Visit_Start_Date"] <="2025-06-26"
cond2 = df_visit_truncated["Visit_Start_Date"] >="2025-06-13"
df_13_26June = df_visit_truncated[cond1 & cond2]
print("First_Week", df_13_26June[cond1 & cond2].shape[0])
df_13_26June.to_excel(r"C:\Users\u291963\Desktop\Ammar\Visits & Complaints\01_July\June13_26.xlsx")

# %%
df_13_26June["نوع الزيارة"].value_counts()

# %%
# How many of the 19428 visits is from CRM Baladi (It should be same as بلاغ مواطن 940	)
df_merged = df_13_26June.merge(df_Complaint, how="inner", on="رقم الزيارة",suffixes=("_visit", "_Complaint"))
print("Visit Shape: ",df_13_26June.shape)
print("Complaint Shape: ",df_Complaint.shape)
print("Merged Shape: ",df_merged.shape)

# %% [markdown]
# ## Visit3 & Visit4

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print(df_13_26June["Visit_Start_Date"].min())
print(df_13_26June["Visit_Start_Date"].max())

# %%
temp = df_13_26June["المنطقة"].value_counts(dropna=False).reset_index()
display(temp["count"].sum())
display(temp)

# %%
temp = df_13_26June["المحافظة"].value_counts(dropna=False).reset_index()
display(temp["count"].sum())
display(temp)

# %%
temp.to_excel(r"C:\Users\u291963\Desktop\temp.xlsx")

# %% [markdown]
# ## Visit5

# %%
df_13_26June.groupby("حالة الزيارة", dropna=False)["Visit_Duration"].agg(["mean", "count"]).reset_index()

# %%
df_13_26June["حالة الزيارة"].value_counts(dropna=False).reset_index()

# %% [markdown]
# ## Merge with Violations

# %%
import pandas as pd
import numpy as np
file_path =r"C:\Users\u291963\Desktop\Ammar\Visits & Complaints\01_July\Copy of All Balady Violations start to (30-6-2025) (002).xlsx"
df_violations = pd.read_excel(file_path)
df_violations.sample(3)

# %%
print(df_violations.shape[0])
print(df_violations.drop_duplicates().shape[0])
print(df_violations.drop_duplicates(subset="معرف المخالفة في النظام").shape[0])
print(df_violations.drop_duplicates(subset="رقم زيارة بلدي").shape[0])

# %%
# Convert its type
DataFrame = df_violations
Start_Date_Time = "تاريخ إنشاء المخالفة / الإستلام من بلدي"	
Start_Date = "Violation_Start_Date"
Start_Time = "Violation_Start_Time"

DataFrame[Start_Date_Time] = pd.to_datetime(DataFrame[Start_Date_Time])
# Extract the columns

## Date
DataFrame[Start_Date] = DataFrame[Start_Date_Time].dt.date
DataFrame[Start_Date] = pd.to_datetime(DataFrame[Start_Date], format='%Y-%m-%d')

## Time
DataFrame[Start_Time]  = DataFrame[Start_Date_Time].dt.time
DataFrame[Start_Time]  = pd.to_datetime(DataFrame[Start_Time] ,format='%H:%M:%S').dt.time

# check
DataFrame.loc[:,[Start_Date_Time, Start_Date, Start_Time]]

# %%
# 13 t0 26 June
cond1 = df_violations["Violation_Start_Date"] <="2025-06-26"
cond2 = df_violations["Violation_Start_Date"] >="2025-06-13"
df_violations_13_26June = df_violations[cond1 & cond2]
print("", df_violations_13_26June[cond1 & cond2].shape[0])
display(df_violations_13_26June.sample(2))

# %%
print(df_violations_13_26June.shape[0])
print(df_violations_13_26June.drop_duplicates(subset="رقم زيارة بلدي").shape[0])
print(df_violations_13_26June.drop_duplicates(subset="معرف المخالفة في النظام").shape[0])

# %%
df_violations_13_26June[df_violations_13_26June.duplicated(subset="رقم زيارة بلدي") == True]

# %%
display(df_violations_13_26June[df_violations_13_26June["رقم زيارة بلدي"] == "SWA-77021"])
display("------------------------------------------")
display(df_violations_13_26June[df_violations_13_26June["رقم زيارة بلدي"] == "SWA-45001"])
display("------------------------------------------")
display(df_violations_13_26June[df_violations_13_26June["رقم زيارة بلدي"] == "SWA-52075"])
display("------------------------------------------")
display(df_violations_13_26June[df_violations_13_26June["رقم زيارة بلدي"] == "SWA-53443"])
display("------------------------------------------")

# %% [markdown]
# Multiple violations, not duplicates

# %%
df_violations_13_26June = df_violations_13_26June.rename({"رقم زيارة بلدي":"رقم الزيارة"} ,axis="columns")

# %%
visit_violation = df_violations_13_26June.merge(df_13_26June, on="رقم الزيارة", how="inner")
print("visit:", df_13_26June.shape )
print("violation:", df_violations_13_26June.shape )
print("merged:", visit_violation.shape )

# %%
# دمج البيانات مع تحديد نوع الدمج على أنه "left" أو "outer"
merged_df = df_violations_13_26June.merge(df_13_26June, on="رقم الزيارة", how="left", indicator=True)

# تصفية النتائج للحصول على المخالفات غير الموجودة في جدول الزيارات
violations_not_in_visit = merged_df[merged_df['_merge'] == 'left_only']

# حساب عدد المخالفات غير الموجودة في جدول الزيارات
num_violations_not_in_visit = len(violations_not_in_visit)

print("عدد المخالفات غير الموجودة في جدول الزيارات:", num_violations_not_in_visit)

# دمج البيانات مع تحديد نوع الدمج على أنه "left"
merged_df = df_violations_13_26June.merge(df_13_26June, on="رقم الزيارة", how="left", indicator=True)

# تصفية النتائج للحصول على المخالفات غير الموجودة في جدول الزيارات
violations_not_in_visit = merged_df[merged_df['_merge'] == 'left_only']

# استخراج قائمة "رقم الزيارة"
visit_numbers = violations_not_in_visit["رقم الزيارة"].tolist()

print("أرقام الزيارات للمخالفات غير الموجودة في جدول الزيارات:", visit_numbers)

# %%
len(visit_numbers)

# %%
visit_violation.columns

# %%
temp = visit_violation[["رقم الزيارة","حالة المخالفة","حالة الزيارة","Visit_Start_Date", "Violation_Start_Date" ]]
cond_1 = temp["Visit_Start_Date"] != temp["Violation_Start_Date"] 
cond_2 = temp["Visit_Start_Date"] == temp["Violation_Start_Date"] 

not_equal = temp[cond_1]
equal = temp[cond_2]

# %%
not_equal.groupby(["حالة الزيارة", "حالة المخالفة"])[["رقم الزيارة"]].agg("count")

# %%
equal.groupby(["حالة الزيارة", "حالة المخالفة"])[["رقم الزيارة"]].agg("count")

# %% [markdown]
# ## Observatory

# %%
file_path = r"C:\Users\u291963\Desktop\Ammar\Visits & Complaints\01_July\المنشورات كاملة (يوليو 2024 - 29 يونيو 2025).xlsx"
df_observatory = pd.read_excel(file_path)
df_observatory
# Out:
#                      Date                                          Post Link  \
# 0     2024-07-30 00:00:00   https://x.com/hhsqour/status/1818259823328141560
# 1     2024-07-28 00:00:00  https://x.com/ASheera14/status/181761275977472...
# 2     2024-07-28 00:00:00  https://x.com/alawialit36/status/1817504787400...
# 3     2024-07-28 00:00:00  https://x.com/0alasire7/status/181747062692525...
# 4     2024-07-27 00:00:00  https://x.com/alfhd12345/status/18172475108572...
# ...                   ...                                                ...
# 8933  2025-06-29 00:00:00  https://x.com/AL_YASMEENAH_/status/19390825875...
# 8934  2025-06-29 00:00:00  https://x.com/md62905088/status/19390821978785...
# 8935  2025-06-29 00:00:00  https://x.com/laithistanbull/status/1939081919...
# 8936  2025-06-29 00:00:00  https://x.com/MAAKAABi/status/1939073975159578789
# 8937  2025-06-29 00:00:00  https://x.com/M_ZAH_1212/status/19390663537568...
#
# ...

# %%
display(df_observatory.groupby(["الأحياء"])["Post Link"].agg("count").reset_index().sort_values("Post Link", ascending=False)["Post Link"].sum())
display(df_observatory.groupby(["الأحياء"])["Post Link"].agg("count").reset_index().sort_values("Post Link", ascending=False).head(20))
# Out:
# np.int64(3157)
#                    الأحياء  Post Link
# 413  حي أبرق الرغامة (جدة)        102
# 960       حي طويق (الرياض)         97
# 588     حي الرمال (الرياض)         95
# 796        حي المروة (جدة)         80
# 855     حي النرجس (الرياض)         65
# 983        حي لبن (الرياض)         49
# 835    حي المهدية (الرياض)         43
# 663     حي الشعلة (الدمام)         40
# 618        حي السامر (جدة)         35
# 829        حي المنار (جدة)         35
# 917        حي بدر (الدمام)         33
# 965          حي طيبة (جدة)         33
# 840   حي المونسية (الرياض)         29
# 517      حي الحزم (الرياض)         27
# 646     حي الشاطئ (الدمام)         25
# 889        حي الواحة (جدة)         25
# 417        حي أحد (الدمام)         23
# 468     حي البديع (الدمام)         22
# 713   حي العزيزية (الرياض)         21
# 865     حي النسيم (الرياض)         21

# %%
import pandas as pd


# Replace (الهفوف) with (الأحساء)
df_observatory.replace({'(الهفوف)': '(الأحساء)'}, regex=True, inplace=True)
df_observatory.sample(3)
# Out:
#              Date                                          Post Link  \
# 5463  07-May-2025   https://x.com/NWCcare/status/1920138667336544446
# 7059  26-May-2025  https://x.com/MajedSB6/status/1926944148893974896
# 1713  04-Feb-2025  https://x.com/mohsen_1995_/status/188661850189...
#
#                                               Post Text              الأحياء  \
# 5463  @wjy_m33292 كما تم افادتك مسبقا بأن التسربات ا...                  NaN
# 7059  @NWCcare  تم طلب توصيل مياه و صرف صحي ودفع الر...                  NaN
# 1713  @swa_care متى ناوين تضخون المياه في الدمام حي ...  حي العروبة (الدمام)
#
#           التحليل المدينة
# 5463         تسرب     NaN
# 7059  طفح صرف صحي     NaN
# 1713       صهاريج  الدمام

# %%
print(df_observatory.shape)
df_observatory_filtered = df_observatory[~df_observatory["المدينة"].isna()]
print(df_observatory_filtered.shape)
# Out:
# (8938, 6)
# (3623, 6)

# %%
print(df_observatory.shape)
df_observatory_filtered["Date"] = pd.to_datetime(df_observatory_filtered["Date"])
cond_1 = df_observatory_filtered["Date"] >= "2025-06-13"
cond_2 = df_observatory_filtered["Date"] <= "2025-06-26"

df_observatory_filtered_13_26_June = df_observatory_filtered[cond_1 & cond_2]
print(df_observatory_filtered_13_26_June.shape)
# Out:
# (8938, 6)
# (125, 6)
# C:\Users\u291963\AppData\Local\Temp\ipykernel_6148\252445861.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_observatory_filtered["Date"] = pd.to_datetime(df_observatory_filtered["Date"])

# %%
indices_list = df_observatory[df_observatory["الأحياء"].str.startswith('حي') == False].index
indices_list
# Out:
# Index([   3,  377,  378,  379,  380,  382,  384,  386,  387,  388,
#        ...
#        8879, 8895, 8897, 8906, 8908, 8909, 8919, 8925, 8926, 8937],
#       dtype='int64', length=739)

# %%
# Convert indices_list elements to integers
indices_list = [int(i) for i in indices_list]

# Add "حي" to the "الأحياء" column for the specified indices
df_observatory.loc[indices_list, "الأحياء"] = "حي " + df_observatory.loc[indices_list, "الأحياء"].astype(str)

# %%
display(df_observatory.groupby(["الأحياء"])["Post Link"].agg("count").reset_index().sort_values("Post Link", ascending=False)["Post Link"].sum())
display(df_observatory.groupby(["الأحياء"])["Post Link"].agg("count").reset_index().sort_values("Post Link", ascending=False).head(20))
# Out:
# np.int64(3157)
#                    الأحياء  Post Link
# 243  حي أبرق الرغامة (جدة)        102
# 916       حي طويق (الرياض)         97
# 461     حي الرمال (الرياض)         95
# 711        حي المروة (جدة)         80
# 787     حي النرجس (الرياض)         65
# 947        حي لبن (الرياض)         49
# 761    حي المهدية (الرياض)         43
# 549     حي الشعلة (الدمام)         40
# 752        حي المنار (جدة)         39
# 496        حي السامر (جدة)         35
# 921          حي طيبة (جدة)         35
# 859        حي بدر (الدمام)         33
# 768   حي المونسية (الرياض)         30
# 611   حي العزيزية (الرياض)         30
# 373      حي الحزم (الرياض)         29
# 825        حي الواحة (جدة)         26
# 529     حي الشاطئ (الدمام)         25
# 264      حي الأجاويد (جدة)         24
# 247        حي أحد (الدمام)         23
# 798     حي النسيم (الرياض)         22

# %%
print(df_observatory_filtered.shape)
df_observatory["Date"] = pd.to_datetime(df_observatory_filtered["Date"])
cond_1 = df_observatory_filtered["Date"] >= "2025-06-13"
cond_2 = df_observatory_filtered["Date"] <= "2025-06-26"

df_observatory_13_26June = df_observatory_filtered[cond_1 & cond_2]
print(df_observatory_13_26June.shape)
# Out:
# (3623, 6)
# (125, 6)

# %% [markdown]
# ## CRM Baladi (01_July)
# this before visit (initiator to visit)

# %%
df_CRM = pd.read_excel(r"C:\Users\u291963\Desktop\Ammar\Visits & Complaints\01_July\CRM Baladi_01_June.xlsx")
print(df_CRM.shape[0])
df_CRM_fixed = df_CRM.drop(["المحافظة"], axis="columns")
display(df_CRM.shape)
display(df_CRM_fixed.shape)
# Out:
# 76620
# (76620, 12)
# (76620, 11)

# %%
df_CRM_fixed = df_CRM_fixed.drop_duplicates()
display(df_CRM_fixed.shape)
# Out:
# (4953, 11)

# %%
df_CRM_fixed.columns
# Out:
# Index(['رقم الزيارة', 'رقم البلاغ', 'مصدر البلاغ', 'التصنيف', 'المنطقة',
#        'حالة البلاغ', 'تاريخ تقديم البلاغ',
#        'حالة البلاغ   لدى محقق الهيئة    مسند', 'هوية المفتش', 'اسم المفتش',
#        'الإحداثيات'],
#       dtype='object')

# %%
# Convert its type
DataFrame = df_CRM_fixed
Start_Date_Time = "تاريخ تقديم البلاغ"	
Start_Date = "Complaint_Start_Date"
Start_Time = "Complaint_Start_Time"

DataFrame[Start_Date_Time] = pd.to_datetime(DataFrame[Start_Date_Time])
# Extract the columns

## Date
DataFrame[Start_Date] = DataFrame[Start_Date_Time].dt.date
DataFrame[Start_Date] = pd.to_datetime(DataFrame[Start_Date], format='%Y-%m-%d')

## Time
DataFrame[Start_Time]  = DataFrame[Start_Date_Time].dt.time
DataFrame[Start_Time]  = pd.to_datetime(DataFrame[Start_Time] ,format='%H:%M:%S').dt.time

# check
DataFrame.loc[:,[Start_Date_Time, Start_Date, Start_Time]]
# Out:
# C:\Users\u291963\AppData\Local\Temp\ipykernel_6148\2265994270.py:7: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   DataFrame[Start_Date_Time] = pd.to_datetime(DataFrame[Start_Date_Time])
#        تاريخ تقديم البلاغ Complaint_Start_Date Complaint_Start_Time
# 0     2025-05-23 17:02:14           2025-05-23             17:02:14
# 2     2025-05-26 10:03:34           2025-05-26             10:03:34
# 5     2025-05-28 19:01:36           2025-05-28             19:01:36
# 8     2025-05-26 08:42:27           2025-05-26             08:42:27
# 10    2025-05-22 15:52:12           2025-05-22             15:52:12
# ...                   ...                  ...                  ...
# 46597 2025-06-07 22:05:52           2025-06-07             22:05:52
# 46971 2025-06-16 19:11:59           2025-06-16             19:11:59
# ...

# %%
df_CRM_fixed
# Out:
#       رقم الزيارة        رقم البلاغ     مصدر البلاغ              التصنيف  \
# 0       SWA-57102  INC-25-05-178055  بلاغ مواطن 940  تسريب او طفح المياه
# 2       SWA-59058  INC-25-05-194322  بلاغ مواطن 940  تسريب او طفح المياه
# 5       SWA-59222  INC-25-05-211632  بلاغ مواطن 940  تسريب او طفح المياه
# 8       SWA-58021  INC-25-05-198508  بلاغ مواطن 940  تسريب او طفح المياه
# 10      SWA-57024  INC-25-05-167650  بلاغ مواطن 940  تسريب او طفح المياه
# ...           ...               ...             ...                  ...
# 46597   SWA-64007  INC-25-06-037750  بلاغ مواطن 940  تسريب او طفح المياه
# 46971   SWA-83101  INC-25-06-099599  بلاغ مواطن 940  تسريب او طفح المياه
# 47664   SWA-75078  INC-25-06-078165  بلاغ مواطن 940  تسريب او طفح المياه
# 47822   SWA-75064  INC-25-06-073414  بلاغ مواطن 940  تسريب او طفح المياه
# 56682   SWA-66016  INC-25-06-041428  بلاغ مواطن 940  تسريب او طفح المياه
#
#            المنطقة                 حالة البلاغ  تاريخ تقديم البلاغ  \
# ...

# %%
df_eastern = df_CRM[df_CRM["المنطقة"] == "الشرقية"]
df_eastern
# Out:
#       رقم الزيارة        رقم البلاغ     مصدر البلاغ              التصنيف  \
# 277     SWA-61336  INC-25-06-016124  بلاغ مواطن 940  تسريب او طفح المياه
# 310     SWA-60086  INC-25-05-202637  بلاغ مواطن 940  تسريب او طفح المياه
# 311     SWA-60086  INC-25-05-202637  بلاغ مواطن 940  تسريب او طفح المياه
# 328     SWA-71059  INC-25-06-074243  بلاغ مواطن 940  تسريب او طفح المياه
# 329     SWA-71059  INC-25-06-074243  بلاغ مواطن 940  تسريب او طفح المياه
# ...           ...               ...             ...                  ...
# 76597   SWA-75068  INC-25-06-077212  بلاغ مواطن 940  تسريب او طفح المياه
# 76598   SWA-84149  INC-25-06-108603  بلاغ مواطن 940  تسريب او طفح المياه
# 76599   SWA-84149  INC-25-06-108603  بلاغ مواطن 940  تسريب او طفح المياه
# 76606   SWA-65033  INC-25-06-046897  بلاغ مواطن 940  تسريب او طفح المياه
# 76616   SWA-59556  INC-25-06-017902  بلاغ مواطن 940  تسريب او طفح المياه
#
#        المنطقة           المحافظة                 حالة البلاغ  \
# ...

# %%
df_Riadh= df_CRM[df_CRM["المنطقة"] == "الرياض"]
# Assuming your DataFrame is named 'df'
counts = df_Riadh['رقم الزيارة'].value_counts()
duplicated_counts = counts[counts > 1]

# duplicated_counts now contains the counts of duplicated values in 'col1'
# To display it as a DataFrame:
duplicated_df = duplicated_counts.reset_index()
duplicated_df.columns = ['رقم الزيارة', 'count']
display(duplicated_df.sort_values("count"))
# Out:
#     رقم الزيارة  count
# 831   SWA-57020     23
# 830   SWA-56049     23
# 829   SWA-56128     23
# 828   SWA-84139     23
# 827   SWA-58113     23
# ..          ...    ...
# 836   SWA-56106     23
# 837   SWA-56103     23
# 838   SWA-55034     23
# 839   SWA-57044     23
# 0     SWA-61019     23
#
# [840 rows x 2 columns]

# %%
# Assuming your DataFrame is named 'df'
counts = df_eastern['رقم الزيارة'].value_counts()
duplicated_counts = counts[counts > 1]

# duplicated_counts now contains the counts of duplicated values in 'col1'
# To display it as a DataFrame:
duplicated_df = duplicated_counts.reset_index()
duplicated_df.columns = ['رقم الزيارة', 'count']
display(duplicated_df)
# Out:
#     رقم الزيارة  count
# 0     SWA-85098     13
# 1     SWA-61336     13
# 2     SWA-83220     13
# 3     SWA-59201     13
# 4     SWA-65099     13
# ..          ...    ...
# 701   SWA-75055     13
# 702   SWA-64073     13
# 703   SWA-65106     13
# 704   SWA-61061     13
# 705   SWA-71059     13
#
# [706 rows x 2 columns]

# %%
df_CRM_fixed.sample(2)
# Out:
#       رقم الزيارة        رقم البلاغ     مصدر البلاغ              التصنيف  \
# 19046   SWA-83355  INC-25-06-140844  بلاغ مواطن 940  تسريب او طفح المياه
# 8957    SWA-57006  INC-25-05-169970  بلاغ مواطن 940  تسريب او طفح المياه
#
#        المنطقة     حالة البلاغ  تاريخ تقديم البلاغ  \
# 19046  الشرقية  مكتملة - ممتثل 2025-06-23 18:34:59
# 8957   الشرقية  مكتملة - ممتثل 2025-05-22 14:08:59
#
#       حالة البلاغ   لدى محقق الهيئة    مسند   هوية المفتش  \
# 19046                                  مسند  1.071883e+09
# 8957                                   مسند  1.063079e+09
#
#                      اسم المفتش                           الإحداثيات  \
# 19046    محمد سعود حمد الشهراني  26.24023897644232,50.20013994905395
# 8957   محمد مهدي بن عباس الصادق  26.43225207076255,50.01699697310517
#
#       Complaint_Start_Date Complaint_Start_Time
# 19046           2025-06-23             18:34:59
# 8957            2025-05-22             14:08:59

# %%
print(df_CRM_fixed.shape)
df_CRM_fixed["Complaint_Start_Date"] = pd.to_datetime(df_CRM_fixed["Complaint_Start_Date"])
cond_1 = df_CRM_fixed["Complaint_Start_Date"] >= "2025-06-13"
cond_2 = df_CRM_fixed["Complaint_Start_Date"] <= "2025-06-26"

df_CRM_fixed_13_26_June = df_CRM_fixed[cond_1 & cond_2]
print(df_CRM_fixed_13_26_June.shape)
# Out:
# (4953, 13)
# (1297, 13)

# %% [markdown]
# ## Triggee by City

# %%
temp = df_CRM_fixed_13_26_June["المنطقة"].value_counts().reset_index()
display(temp["count"].sum())
display(temp)
# Out:
# np.int64(1297)
#             المنطقة  count
# 0       مكة المكرمة    382
# 1            الرياض    204
# 2           الشرقية    188
# 3   المدينة المنورة    130
# 4            القصيم    106
# 5             جازان     76
# 6              عسير     57
# 7              تبوك     54
# 8             الجوف     44
# 9              حائل     34
# 10            نجران      8
# 11  الحدود الشمالية      8
# 12           الباحة      6

# %%
df_observatory_13_26June["المدينة"].value_counts().reset_index()
# Out:
#             المدينة  count
# 0            الرياض     40
# 1               جدة     26
# 2              جدة       6
# 3   المدينة المنورة      5
# 4             جيزان      5
# 5            سكاكا       3
# 6             الخبر      3
# 7         خميس مشيط      3
# 8              أبها      3
# 9           الدمام       3
# 10            ينبع       2
# 11           جازان       2
# 12             مكة       2
# 13       خميس مشيط       2
# 14          الرياض       1
# 15         الاحساء       1
# 16             حائل      1
# 17           القطيف      1
# 18      مكة المكرمة      1
# 19           بريدة       1
# 20           بلجرشي      1
# 21         القنفذة       1
# 22           الباحة      1
# 23           الطائف      1
# 24        أحد رفيدة      1
# 25         الأحساء       1
# 26             رماح      1
# 27             ينبع      1
# 28            جازان      1
# 29            الجوف      1
# 30              مكة      1
# 31            نجران      1
# 32          القصيم       1
# ...

# %% [markdown]
# ## Trigger Volume by Issue Type

# %%
temp = df_observatory_13_26June["التحليل"].value_counts().reset_index()
display(temp["count"].sum())
display(temp)
# Out:
# np.int64(125)
#                التحليل  count
# 0        انقطاع المياه     45
# 1                 تسرب     22
# 2        خدمات لاشبكية     11
# 3          طفح صرف صحي     10
# 4                 جودة      6
# 5         مشكلات تقنية      5
# 6   امداد شبكة صرف صحي      4
# 7       أعطال العدادات      4
# 8               حفريات      3
# 9      إمداد شبكة مياه      3
# 10     امداد شبكة مياه      2
# 11     تأسيس عداد مياه      2
# 12      خدمات لا شبكية      1
# 13                تلوث      1
# 14        طفح صرف صحي       1
# 15               جودة       1
# 16   الفواتير والأسعار      1
# 17        أنظمة ولوائح      1
# 18        فوترة ومالية      1
# 19   توصيل شبكة المياه      1

# %%
df_CRM_fixed_13_26_June.columns
# Out:
# Index(['رقم الزيارة', 'رقم البلاغ', 'مصدر البلاغ', 'التصنيف', 'المنطقة',
#        'حالة البلاغ', 'تاريخ تقديم البلاغ',
#        'حالة البلاغ   لدى محقق الهيئة    مسند', 'هوية المفتش', 'اسم المفتش',
#        'الإحداثيات', 'Complaint_Start_Date', 'Complaint_Start_Time'],
#       dtype='object')

# %%
df_CRM_fixed_13_26_June["التصنيف"].value_counts().reset_index()
# Out:
#                التصنيف  count
# 0  تسريب او طفح المياه   1297

# %% [markdown]
# ## trigger Volume by Time
# using commulative data not jsut 13 to 26

# %% [markdown]
# ### CRM Baladi

# %%
import pandas as pd

# Assuming your DataFrame is named df_CRM_fixed and the date column is "Complaint_Start_Date"

# Convert 'Visit_Start_Date' to datetime objects
df_CRM_fixed['Complaint_Start_Date'] = pd.to_datetime(df_CRM_fixed['Complaint_Start_Date'])

# Define the end date of your main range
end_date = pd.to_datetime('2025-06-26')

# Define the start date of your main range
start_date = pd.to_datetime('2025-06-20')

# Calculate visits in the main date range (2025-06-20 to 2025-06-26)
main_range_visits = df_CRM_fixed[(df_CRM_fixed['Complaint_Start_Date'] >= start_date) & (df_CRM_fixed['Complaint_Start_Date'] <= end_date)].shape[0]

print(f"Complaints from 2025-06-20 to 2025-06-26: {main_range_visits}")

# Calculate visits for each preceding week
current_start = start_date - pd.Timedelta(days=7)
current_end = start_date - pd.Timedelta(days=1)

while current_start >= df_CRM_fixed['Complaint_Start_Date'].min():  # Assuming you want to stop at the earliest date in your data
    weekly_visits = df_CRM_fixed[(df_CRM_fixed['Complaint_Start_Date'] >= current_start) & (df_CRM_fixed['Complaint_Start_Date'] <= current_end)].shape[0]
    print(f"Complaints from {current_start.strftime('%Y-%m-%d')} to {current_end.strftime('%Y-%m-%d')}: {weekly_visits}")
    
    # Move to the previous week
    current_end = current_start - pd.Timedelta(days=1)
    current_start = current_start - pd.Timedelta(days=7)
# Out:
# Complaints from 2025-06-20 to 2025-06-26: 459
# Complaints from 2025-06-13 to 2025-06-19: 838
# Complaints from 2025-06-06 to 2025-06-12: 781
# Complaints from 2025-05-30 to 2025-06-05: 1190
# Complaints from 2025-05-23 to 2025-05-29: 1438

# %%
459+838
# Out:
# 1297

# %% [markdown]
# ### Observatory

# %%
import pandas as pd

# Assuming your DataFrame is named df_observatory and the date column is "Date"

# Convert 'Visit_Start_Date' to datetime objects
df_observatory['Date'] = pd.to_datetime(df_observatory['Date'])

# Define the end date of your main range
end_date = pd.to_datetime('2025-06-26')

# Define the start date of your main range
start_date = pd.to_datetime('2025-06-20')

# Calculate visits in the main date range (2025-06-20 to 2025-06-26)
main_range_visits = df_observatory[(df_observatory['Date'] >= start_date) & (df_observatory['Date'] <= end_date)].shape[0]

print(f"Social Posts from 2025-06-20 to 2025-06-26: {main_range_visits}")

# Calculate visits for each preceding week
current_start = start_date - pd.Timedelta(days=7)
current_end = start_date - pd.Timedelta(days=1)

while current_start >= df_observatory['Date'].min():  # Assuming you want to stop at the earliest date in your data
    weekly_visits = df_observatory[(df_observatory['Date'] >= current_start) & (df_observatory['Date'] <= current_end)].shape[0]
    print(f"Social Posts from {current_start.strftime('%Y-%m-%d')} to {current_end.strftime('%Y-%m-%d')}: {weekly_visits}")
    
    # Move to the previous week
    current_end = current_start - pd.Timedelta(days=1)
    current_start = current_start - pd.Timedelta(days=7)
# Out:
# Social Posts from 2025-06-20 to 2025-06-26: 281
# Social Posts from 2025-06-13 to 2025-06-19: 363
# Social Posts from 2025-06-06 to 2025-06-12: 293
# Social Posts from 2025-05-30 to 2025-06-05: 497
# Social Posts from 2025-05-23 to 2025-05-29: 560
# Social Posts from 2025-05-16 to 2025-05-22: 522
# Social Posts from 2025-05-09 to 2025-05-15: 513
# Social Posts from 2025-05-02 to 2025-05-08: 812
# Social Posts from 2025-04-25 to 2025-05-01: 123
# Social Posts from 2025-04-18 to 2025-04-24: 45
# Social Posts from 2025-04-11 to 2025-04-17: 60
# Social Posts from 2025-04-04 to 2025-04-10: 83
# Social Posts from 2025-03-28 to 2025-04-03: 167
# Social Posts from 2025-03-21 to 2025-03-27: 71
# Social Posts from 2025-03-14 to 2025-03-20: 2070
# Social Posts from 2025-03-07 to 2025-03-13: 94
# Social Posts from 2025-02-28 to 2025-03-06: 85
# Social Posts from 2025-02-21 to 2025-02-27: 74
# Social Posts from 2025-02-14 to 2025-02-20: 68
# Social Posts from 2025-02-07 to 2025-02-13: 95
# ...

# %%
import pandas as pd

# Assuming your DataFrame is named df_observatory_filtered and the date column is "Date"

# Convert 'Visit_Start_Date' to datetime objects
df_observatory_filtered['Date'] = pd.to_datetime(df_observatory_filtered['Date'])

# Define the end date of your main range
end_date = pd.to_datetime('2025-06-26')

# Define the start date of your main range
start_date = pd.to_datetime('2025-06-20')

# Calculate visits in the main date range (2025-06-20 to 2025-06-26)
main_range_visits = df_observatory_filtered[(df_observatory_filtered['Date'] >= start_date) & (df_observatory_filtered['Date'] <= end_date)].shape[0]

print(f"Social Posts from 2025-06-20 to 2025-06-26: {main_range_visits}")

# Calculate visits for each preceding week
current_start = start_date - pd.Timedelta(days=7)
current_end = start_date - pd.Timedelta(days=1)

while current_start >= df_observatory_filtered['Date'].min():  # Assuming you want to stop at the earliest date in your data
    weekly_visits = df_observatory_filtered[(df_observatory_filtered['Date'] >= current_start) & (df_observatory_filtered['Date'] <= current_end)].shape[0]
    print(f"Social Posts from {current_start.strftime('%Y-%m-%d')} to {current_end.strftime('%Y-%m-%d')}: {weekly_visits}")
    
    # Move to the previous week
    current_end = current_start - pd.Timedelta(days=1)
    current_start = current_start - pd.Timedelta(days=7)
# Out:
# Social Posts from 2025-06-20 to 2025-06-26: 53
# Social Posts from 2025-06-13 to 2025-06-19: 72
# Social Posts from 2025-06-06 to 2025-06-12: 70
# Social Posts from 2025-05-30 to 2025-06-05: 116
# Social Posts from 2025-05-23 to 2025-05-29: 114
# Social Posts from 2025-05-16 to 2025-05-22: 145
# Social Posts from 2025-05-09 to 2025-05-15: 217
# Social Posts from 2025-05-02 to 2025-05-08: 75
# Social Posts from 2025-04-25 to 2025-05-01: 37
# Social Posts from 2025-04-18 to 2025-04-24: 45
# Social Posts from 2025-04-11 to 2025-04-17: 60
# Social Posts from 2025-04-04 to 2025-04-10: 83
# Social Posts from 2025-03-28 to 2025-04-03: 167
# Social Posts from 2025-03-21 to 2025-03-27: 71
# Social Posts from 2025-03-14 to 2025-03-20: 84
# Social Posts from 2025-03-07 to 2025-03-13: 94
# Social Posts from 2025-02-28 to 2025-03-06: 85
# Social Posts from 2025-02-21 to 2025-02-27: 74
# Social Posts from 2025-02-14 to 2025-02-20: 68
# Social Posts from 2025-02-07 to 2025-02-13: 95
# ...

# %% [markdown]
# ## Website Incidents

# %%
file_path = r"C:\Users\u291963\Desktop\Ammar\Visits & Complaints\01_July\تقرير_البلاغات_20250702_1320 (1).xlsx"
df_WebInc = pd.read_excel(file_path)
df_WebInc
# Out:
#       رقم البلاغ               الحالة                نوع البلاغ  كمية التسرب  \
# 0           1324                 جديد             طفح من الشبكة   سريان مياه
# 1           1323                 جديد  تسريب من الشبكة الرئيسية   سريان مياه
# 2           1322                 جديد             طفح من الشبكة   تجمع مياه
# 3           1321                 جديد             طفح من الشبكة   سريان مياه
# 4           1320                 جديد               سوء استخدام   تجمع مياه
# ...          ...                  ...                       ...          ...
# 1319           5  مرفوض لعدم الاختصاص                      مياه   سريان مياه
# 1320           4                مكتمل                      مياه   سريان مياه
# 1321           3                مكتمل                      مياه   سريان مياه
# 1322           2                مكتمل                      مياه   سريان مياه
# 1323           1                مكتمل                      مياه   سريان مياه
#
# ...

# %%
print(df_WebInc.shape)
print(df_WebInc.drop_duplicates().shape)
# Out:
# (1324, 24)
# (1324, 24)

# %%
df_WebInc.sample()
# Out:
#      رقم البلاغ الحالة نوع البلاغ كمية التسرب  تاريخ الإنشاء (السنة)  \
# 855         469  مرفوض    صرف صحي  تجمع مياه                    2025
#
#      تاريخ الإنشاء (اليوم) تاريخ الإنشاء (الشهر) تاريخ الإنشاء (الشهر).1  \
# 855                     22            2025-04-01              2025-04-01
#
#     تاريخ الإنشاء (مفهوم)   تاريخ الإنشاء  ... تاريخ الإغلاق (الشهر).1  \
# 855            2025-04-22  أبريل 22, 2025  ...              2025-06-01
#
#      تاريخ الإغلاق (مفهوم)  Unnamed: 16  \
# 855             2025-06-04          NaN
#
#                                          تفاصيل البلاغ            المنطقة  \
# 855  تسريب صرف صحي من المبنى الموجود في الصورة بشكل...  منطقة مكة المكرمة
#
#     الرمز البريدي  المدينة   خط الطول   خط العرض             رابط الموقع
# 855         22265      جدة  39.258298  21.519583  فتح الموقع في قوقل ماب
#
# [1 rows x 24 columns]

# %%
df_WebInc["Open Date"] = pd.to_datetime(df_WebInc["تاريخ الإنشاء (مفهوم)"])
df_WebInc["Close Date"] = pd.to_datetime(df_WebInc["تاريخ الإغلاق (مفهوم)"])
df_WebInc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1324 entries, 0 to 1323
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   رقم البلاغ               1324 non-null   int64
#  1   الحالة                   1324 non-null   object
#  2   نوع البلاغ               1324 non-null   object
#  3   كمية التسرب              1324 non-null   object
#  4   تاريخ الإنشاء (السنة)    1324 non-null   int64
#  5   تاريخ الإنشاء (اليوم)    1324 non-null   int64
#  6   تاريخ الإنشاء (الشهر)    1324 non-null   datetime64[ns]
#  7   تاريخ الإنشاء (الشهر).1  1324 non-null   datetime64[ns]
#  8   تاريخ الإنشاء (مفهوم)    1324 non-null   datetime64[ns]
#  9   تاريخ الإنشاء            1324 non-null   object
#  10  تاريخ الإغلاق            539 non-null    object
#  11  تاريخ الإغلاق (السنة)    539 non-null    float64
#  12  تاريخ الإغلاق (اليوم)    539 non-null    float64
# ...

# %%
print(df_WebInc.shape)
cond_1 = df_WebInc["Open Date"] >= "2025-06-13"
cond_2 = df_WebInc["Open Date"] <= "2025-06-26"

df_WebInc_13_26_June = df_WebInc[cond_1 & cond_2]
print(df_WebInc_13_26_June.shape)
# Out:
# (1324, 26)
# (195, 26)

# %%
df_WebInc_13_26_June["المنطقة"].value_counts(dropna=False).reset_index()
# Out:
#                   المنطقة  count
# 0       منطقة مكة المكرمة     56
# 1            منطقة الرياض     42
# 2         المنطقة الشرقية     29
# 3   منطقة المدينة المنورة     27
# 4             منطقة جازان     12
# 5             منطقة الجوف     11
# 6                     NaN      4
# 7              منطقة تبوك      3
# 8            منطقة القصيم      3
# 9            منطقة الباحة      3
# 10             منطقة حائل      3
# 11             منطقة عسير      2

# %%
df_WebInc_13_26_June["نوع البلاغ"].value_counts(dropna=False).reset_index()
# Out:
#                  نوع البلاغ  count
# 0               طفح من عقار    101
# 1  تسريب من الشبكة الرئيسية     36
# 2             طفح من الشبكة     27
# 3               سوء استخدام     14
# 4           تسريب من العداد     10
# 5               جودة المياه      4
# 6                    صهاريج      3

# %%
import pandas as pd

# Assuming your DataFrame is named df_WebInc and the date column is "Open Date"

# Convert 'Visit_Start_Date' to datetime objects
df_WebInc['Open Date'] = pd.to_datetime(df_WebInc['Open Date'])

# Define the end date of your main range
end_date = pd.to_datetime('2025-06-26')

# Define the start date of your main range
start_date = pd.to_datetime('2025-06-20')

# Calculate visits in the main date range (2025-06-20 to 2025-06-26)
main_range_visits = df_WebInc[(df_WebInc['Open Date'] >= start_date) & (df_WebInc['Open Date'] <= end_date)].shape[0]

print(f"Incdidents from 2025-06-20 to 2025-06-26: {main_range_visits}")

# Calculate visits for each preceding week
current_start = start_date - pd.Timedelta(days=7)
current_end = start_date - pd.Timedelta(days=1)

while current_start >= df_WebInc['Open Date'].min():  # Assuming you want to stop at the earliest date in your data
    weekly_visits = df_WebInc[(df_WebInc['Open Date'] >= current_start) & (df_WebInc['Open Date'] <= current_end)].shape[0]
    print(f"Incdidents from {current_start.strftime('%Y-%m-%d')} to {current_end.strftime('%Y-%m-%d')}: {weekly_visits}")
    
    # Move to the previous week
    current_end = current_start - pd.Timedelta(days=1)
    current_start = current_start - pd.Timedelta(days=7)
# Out:
# Incdidents from 2025-06-20 to 2025-06-26: 100
# Incdidents from 2025-06-13 to 2025-06-19: 95
# Incdidents from 2025-06-06 to 2025-06-12: 68
# Incdidents from 2025-05-30 to 2025-06-05: 53
# Incdidents from 2025-05-23 to 2025-05-29: 113
# Incdidents from 2025-05-16 to 2025-05-22: 179
# Incdidents from 2025-05-09 to 2025-05-15: 74
# Incdidents from 2025-05-02 to 2025-05-08: 37
# Incdidents from 2025-04-25 to 2025-05-01: 36
# Incdidents from 2025-04-18 to 2025-04-24: 46
# Incdidents from 2025-04-11 to 2025-04-17: 39
# Incdidents from 2025-04-04 to 2025-04-10: 37
# Incdidents from 2025-03-28 to 2025-04-03: 36
# Incdidents from 2025-03-21 to 2025-03-27: 41
# Incdidents from 2025-03-14 to 2025-03-20: 23
# Incdidents from 2025-03-07 to 2025-03-13: 35
# Incdidents from 2025-02-28 to 2025-03-06: 53
# Incdidents from 2025-02-21 to 2025-02-27: 12
# Incdidents from 2025-02-14 to 2025-02-20: 11
# Incdidents from 2025-02-07 to 2025-02-13: 20
# Incdidents from 2025-01-31 to 2025-02-06: 22
# ...

# %% [markdown]
# ## Visit volume by trigger type

# %%
display(df_CRM_fixed_13_26_June.shape)
display(df_visit_truncated.shape)
# Out:
# (1297, 13)
# (19428, 29)

# %%
display(df_visit_truncated.shape)
cond_1 = df_visit_truncated["Visit_Start_Date"] >= "2025-06-13"
cond_2 = df_visit_truncated["Visit_Start_Date"] <= "2025-06-26"
df_visit_truncated_13_26_June = df_visit_truncated[cond_1 & cond_2]
display(df_visit_truncated_13_26_June.shape)
# Out:
# (19428, 29)
# (2698, 29)

# %%
df_CRM_fixed.merge(df_visit_truncated, how="inner", on="رقم الزيارة").shape
# Out:
# (2387, 41)

# %%
df_CRM_fixed_13_26_June.merge(df_visit_truncated_13_26_June, how="inner", on="رقم الزيارة").shape
# Out:
# (549, 41)

# %%
# 13_to26 June

# Assuming your DataFrames are named df_CRM_fixed_13_26_June and df_visit_truncated_13_26_June
# and the column you're interested in is named 'رقم الزيارة'

# Create a boolean Series indicating whether each value in df_CRM_fixed_13_26_June['رقم الزيارة']
# is present in df_visit_truncated_13_26_June['رقم الزيارة']
is_present = df_CRM_fixed_13_26_June['رقم الزيارة'].isin(df_visit_truncated_13_26_June['رقم الزيارة'])

# Count the number of True values in the is_present Series
count = is_present.sum()

print(f"Number of 'رقم الزيارة' values in df_CRM_fixed_13_26_June that are also in df_visit_truncated_13_26_June: {count}")
# Out:
# Number of 'رقم الزيارة' values in df_CRM_fixed_13_26_June that are also in df_visit_truncated_13_26_June: 549

# %%
# Comulative


# Assuming your DataFrames are named df_CRM_fixed_13_26_June and df_visit_truncated_13_26_June
# and the column you're interested in is named 'رقم الزيارة'

# Create a boolean Series indicating whether each value in df_CRM_fixed_13_26_June['رقم الزيارة']
# is present in df_visit_truncated_13_26_June['رقم الزيارة']
is_present = df_CRM_fixed['رقم الزيارة'].isin(df_visit_truncated['رقم الزيارة'])

# Count the number of True values in the is_present Series
count = is_present.sum()

print(f"Number of 'رقم الزيارة' values in df_CRM_fixed_13_26_June that are also in df_visit_truncated_13_26_June: {count}")
# Out:
# Number of 'رقم الزيارة' values in df_CRM_fixed_13_26_June that are also in df_visit_truncated_13_26_June: 2385

# %% [markdown]
# ## Visit Volume Over Time

# %%
df_visit_truncated.shape
# Out:
# (19428, 29)

# %%
import pandas as pd

# Assuming your DataFrame is named df_visit_truncated and the date column is "Visit_Start_Date"

# Convert 'Visit_Start_Date' to datetime objects
df_visit_truncated['Visit_Start_Date'] = pd.to_datetime(df_visit_truncated['Visit_Start_Date'])

# Define the end date of your main range
end_date = pd.to_datetime('2025-06-26')

# Define the start date of your main range
start_date = pd.to_datetime('2025-06-20')

# Calculate visits in the main date range (2025-06-20 to 2025-06-26)
main_range_visits = df_visit_truncated[(df_visit_truncated['Visit_Start_Date'] >= start_date) & (df_visit_truncated['Visit_Start_Date'] <= end_date)].shape[0]

print(f"Complaints from 2025-06-20 to 2025-06-26: {main_range_visits}")

# Calculate visits for each preceding week
current_start = start_date - pd.Timedelta(days=7)
current_end = start_date - pd.Timedelta(days=1)

while current_start >= df_visit_truncated['Visit_Start_Date'].min():  # Assuming you want to stop at the earliest date in your data
    weekly_visits = df_visit_truncated[(df_visit_truncated['Visit_Start_Date'] >= current_start) & (df_visit_truncated['Visit_Start_Date'] <= current_end)].shape[0]
    print(f"Complaints from {current_start.strftime('%Y-%m-%d')} to {current_end.strftime('%Y-%m-%d')}: {weekly_visits}")
    
    # Move to the previous week
    current_end = current_start - pd.Timedelta(days=1)
    current_start = current_start - pd.Timedelta(days=7)
# Out:
# Complaints from 2025-06-20 to 2025-06-26: 1168
# Complaints from 2025-06-13 to 2025-06-19: 1530
# Complaints from 2025-06-06 to 2025-06-12: 703
# Complaints from 2025-05-30 to 2025-06-05: 1367
# Complaints from 2025-05-23 to 2025-05-29: 1950
# Complaints from 2025-05-16 to 2025-05-22: 1301
# Complaints from 2025-05-09 to 2025-05-15: 2883
# Complaints from 2025-05-02 to 2025-05-08: 2155
# Complaints from 2025-04-25 to 2025-05-01: 1367
# Complaints from 2025-04-18 to 2025-04-24: 1049
# Complaints from 2025-04-11 to 2025-04-17: 1006
# Complaints from 2025-04-04 to 2025-04-10: 668
# Complaints from 2025-03-28 to 2025-04-03: 283
# Complaints from 2025-03-21 to 2025-03-27: 304
# Complaints from 2025-03-14 to 2025-03-20: 325
# Complaints from 2025-03-07 to 2025-03-13: 233
# Complaints from 2025-02-28 to 2025-03-06: 137
# Complaints from 2025-02-21 to 2025-02-27: 174
# Complaints from 2025-02-14 to 2025-02-20: 181
# Complaints from 2025-02-07 to 2025-02-13: 169
# ...

# %% [markdown]
# ## Visit Volume by City

# %%
display(df_visit_truncated.shape)
cond_1 = df_visit_truncated["Visit_Start_Date"] >= "2025-06-13"
cond_2 = df_visit_truncated["Visit_Start_Date"] <= "2025-06-26"
df_visit_truncated_13_26_June = df_visit_truncated[cond_1 & cond_2]
display(df_visit_truncated_13_26_June.shape)
# Out:
# (19428, 29)
# (2698, 29)

# %%
temp = df_visit_truncated_13_26_June["المنطقة"].value_counts(dropna=False).reset_index()
display(temp["count"].sum())
display(temp)
# Out:
# np.int64(2698)
#             المنطقة  count
# 0       مكة المكرمة    674
# 1            الرياض    522
# 2           الشرقية    432
# 3   المدينة المنورة    254
# 4            القصيم    149
# 5              عسير    133
# 6               NaN    117
# 7             الجوف    110
# 8             جازان     94
# 9            الباحة     79
# 10             حائل     71
# 11            نجران     27
# 12  الحدود الشمالية     19
# 13             تبوك     17

# %% [markdown]
# ## Visit Outcome by Decision & Duration

# %%
display(df_visit_truncated_13_26_June["حالة الزيارة"].value_counts(dropna=False).reset_index())
display(df_visit_truncated_13_26_June.groupby(["حالة الزيارة"])["Visit_Duration"].agg(("count", "mean")))
# Out:
#                  حالة الزيارة  count
# 0     تم ارسالها للنظر والفصل   1043
# 1  بانتظار المراجعة والاعتماد    503
# 2             بانتظار التفتيش    399
# 3           مرسلة الى الأرشيف    352
# 4              مكتملة - ممتثل    328
# 5        لا يوجد بيانات مخالف     73
#                             count                      mean
# حالة الزيارة
# بانتظار التفتيش                 0                       NaT
# بانتظار المراجعة والاعتماد    503 0 days 07:15:16.769383697
# تم ارسالها للنظر والفصل      1043 0 days 00:43:34.177372962
# لا يوجد بيانات مخالف           73 0 days 00:19:28.616438356
# مرسلة الى الأرشيف             352 0 days 06:34:21.792613636
# مكتملة - ممتثل                328 3 days 19:20:11.060975609

# %% [markdown]
# ## Visit volume by Issue Type

# %%
df_visit_truncated_13_26_June.columns
# Out:
# Index(['رقم الزيارة', 'معرف المخالفة', 'نوع الزيارة', 'حالة الزيارة',
#        'تاريخ انشاء الزيارة', 'تاريخ انهاء الزيارة', 'الاحداثيات', 'المنطقة',
#        'المحافظة', 'هوية المراقب', 'اسم المراقب', 'هاتف المراقب',
#        'ايميل المراقب', 'القطاع', 'رقم الرخصة', 'اسم المنشاة', 'مرحلة الى',
#        'التصنيف الرئيسي', 'التصنيف الفرعي', 'قرار مدير الرقابة', 'سبب القرار',
#        'معرف العقار', 'نوع العقار', 'تاريخ اعتماد المخالفة',
#        'Visit_Start_Date', 'Visit_Start_Time', 'Visit_End_Date',
#        'Visit_End_Time', 'Visit_Duration'],
#       dtype='object')

# %%
display(df_visit_truncated_13_26_June['التصنيف الفرعي'].value_counts(dropna=False).reset_index())
# Out:
#                               التصنيف الفرعي  count
# 0                             تسرب شبكة مياه   1287
# 1                               تسرب من عقار    833
# 2                                الصرف الصحي    439
# 3                                        NaN    116
# 4                      تسرب مياه من الصهاريج     14
# 5  مزاولة العمل بالأشياب دون الحصول على رخصة      9

# %% [markdown]
# ## Average Duration Across Violation Workflow Steps

# %%
import pandas as pd
import numpy as np
file_path =r"C:\Users\u291963\Desktop\Ammar\Visits & Complaints\01_July\All Balady Violations start to (30-6-2025).xlsx"
df_violations = pd.read_excel(file_path)
df_violations.sample(3)
# Out:
#      رقم زيارة بلدي  معرف المخالفة في النظام  \
# 2845      SWA-54617                     4566
# 1352      SWA-54071                     3073
# 988       SWA-49115                     2709
#
#                                           حالة المخالفة  \
# 2845  جديد من ممتثل (تم اعادتها إلى مأمور الضبط عبر ...
# 1352  جديد من ممتثل (تم اعادتها إلى مأمور الضبط عبر ...
# 988                                               مكتمل
#
#                                            نوع المخالفة  \
# 2845  عدم توفير أو تركيب مصائد الدهون أو الزيوت من ق...
# 1352  إلقاء أو وضع أو التسبب في وصول مواد ضارة، صلبة...
# 988   عدم توفير أو تركيب مصائد الدهون أو الزيوت من ق...
#
#                                             وصف لمخالفة        منشأة المأمور  \
# 2845  عدم توفير أو تركيب مصائد الدهون أو الزيوت من ق...  شركة المياه الوطنية
# 1352  إلقاء أو وضع أو التسبب في وصول مواد ضارة، صلبة...  شركة المياه الوطنية
# 988   عدم توفير أو تركيب مصائد الدهون أو الزيوت من ق...  شركة المياه الوطنية
#
# ...

# %%
print(df_violations.shape)
print(df_violations.drop_duplicates().shape)
# Out:
# (3799, 15)
# (3799, 15)

# %%
df_violations.sample()
# Out:
#     رقم زيارة بلدي  معرف المخالفة في النظام  \
# 227       SWA-4040                     1777
#
#                                          حالة المخالفة  \
# 227  جديد من ممتثل (تم اعادتها إلى مأمور الضبط عبر ...
#
#                                           نوع المخالفة  \
# 227  تدفق المياه خارج حدود المباني العامة والخاصة، ...
#
#                                    وصف لمخالفة           منشأة المأمور  \
# 227  تدفق المياه خارج المباني العامة أو الخاصة  الهيئة السعودية للمياه
#
#       مأمور الضبط                                      موقع المخالفة  \
# 227  يحيى الخميسي  رقم 54, العليا, الرياض, محافظة الرياض, منطقة ا...
#
#     تاريخ إنشاء المخالفة / الإستلام من بلدي تاريخ الارسال للمخالف  \
# 227                     2025-03-25 20:22:00                   NaT
#
#     تاريخ رد المخالف والوصول الى امانة اللجنة تاريخ الارسال الى اللجنة  \
# 227                                       NaT                      NaT
#
#     تاريخ الارسال الى معالي رئيس الهيئة تاريخ قرار معالي رئيس الهيئة  \
# ...

# %%
temp = df_violations["حالة المخالفة"].value_counts(dropna=False).reset_index()
display(temp["count"].sum())
display(temp)
# Out:
# np.int64(3799)
#                                        حالة المخالفة  count
# 0  جديد من ممتثل (تم اعادتها إلى مأمور الضبط عبر ...   3368
# 1                                              مكتمل    178
# 2                       تم إرجاعه من قبل أمين اللجنة     77
# 3                                   في عملية التصويت     64
# 4                             قيد مراجعة رئيس الهيئة     59
# 5                                قيد مراجعة المستخدم     28
# 6                                  قيد مراجعة اللجنة     22
# 7                           تم إرجاعه لإعادة التصويت      3

# %%
### Filter date
display(df_violations.shape)
cond_1 = df_violations["تاريخ إنشاء المخالفة / الإستلام من بلدي"] >= "2025-06-13"
cond_2 = df_violations["تاريخ إنشاء المخالفة / الإستلام من بلدي"] <= "2025-06-26"
df_violations_13_26_June = df_violations[cond_1 & cond_2]
display(df_violations_13_26_June.shape)
# Out:
# (3799, 20)
# (673, 20)

# %% [markdown]
# ### Convert into Date Type

# %%
DataFrame = df_violations_13_26_June

# Convert its type
Start_Date_Time_1 = "تاريخ إنشاء المخالفة / الإستلام من بلدي"

DataFrame[Start_Date_Time_1] = pd.to_datetime(DataFrame[Start_Date_Time_1])
#--------------------------------------------------------------------------
# Convert its type
Start_Date_Time_2 = "تاريخ الارسال للمخالف"

DataFrame[Start_Date_Time_2] = pd.to_datetime(DataFrame[Start_Date_Time_2])
#--------------------------------------------------------------------------
# Convert its type
Start_Date_Time_3 = "تاريخ رد المخالف والوصول الى امانة اللجنة"

DataFrame[Start_Date_Time_3] = pd.to_datetime(DataFrame[Start_Date_Time_3])
#--------------------------------------------------------------------------
# Convert its type
Start_Date_Time_4 = "تاريخ الارسال الى اللجنة"

DataFrame[Start_Date_Time_4] = pd.to_datetime(DataFrame[Start_Date_Time_4])
#--------------------------------------------------------------------------
# Convert its type
Start_Date_Time_5 = "تاريخ الارسال الى معالي رئيس الهيئة"

DataFrame[Start_Date_Time_5] = pd.to_datetime(DataFrame[Start_Date_Time_5])
#--------------------------------------------------------------------------
# Convert its type
Start_Date_Time_6 = "تاريخ قرار معالي رئيس الهيئة"

DataFrame[Start_Date_Time_6] = pd.to_datetime(DataFrame[Start_Date_Time_6])
#--------------------------------------------------------------------------
DataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 673 entries, 2919 to 3591
# Data columns (total 20 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   رقم زيارة بلدي                             673 non-null    object
#  1   معرف المخالفة في النظام                    673 non-null    int64
#  2   حالة المخالفة                              673 non-null    object
#  3   نوع المخالفة                               673 non-null    object
#  4   وصف لمخالفة                                673 non-null    object
#  5   منشأة المأمور                              673 non-null    object
#  6   مأمور الضبط                                673 non-null    object
#  7   موقع المخالفة                              673 non-null    object
#  8   تاريخ إنشاء المخالفة / الإستلام من بلدي    673 non-null    datetime64[ns]
#  9   تاريخ الارسال للمخالف                      19 non-null     datetime64[ns]
# ...

# %%
temp = df_violations_13_26_June["حالة المخالفة"].value_counts(dropna=False).reset_index()
display(temp["count"].sum())
display(temp)
# Out:
# np.int64(673)
#                                        حالة المخالفة  count
# 0  جديد من ممتثل (تم اعادتها إلى مأمور الضبط عبر ...    654
# 1                                   في عملية التصويت      9
# 2                                  قيد مراجعة اللجنة      6
# 3                             قيد مراجعة رئيس الهيئة      2
# 4                       تم إرجاعه من قبل أمين اللجنة      1
# 5                                              مكتمل      1

# %% [markdown]
# ### Create Duration columns

# %%
Duration = "1_2"
DataFrame[Duration] = DataFrame[Start_Date_Time_2] - DataFrame[Start_Date_Time_1]
DataFrame.loc[:,[Start_Date_Time_2,Start_Date_Time_1,Duration]]
#------------------------------------------------------------
Duration = "2_3"
DataFrame[Duration] = DataFrame[Start_Date_Time_3] - DataFrame[Start_Date_Time_2]
DataFrame.loc[:,[Start_Date_Time_3,Start_Date_Time_2,Duration]]
#------------------------------------------------------------
Duration = "3_4"
DataFrame[Duration] = DataFrame[Start_Date_Time_4] - DataFrame[Start_Date_Time_3]
DataFrame.loc[:,[Start_Date_Time_4,Start_Date_Time_3,Duration]]
#------------------------------------------------------------
Duration = "4_5"
DataFrame[Duration] = DataFrame[Start_Date_Time_5] - DataFrame[Start_Date_Time_4]
DataFrame.loc[:,[Start_Date_Time_5,Start_Date_Time_4,Duration]]
#------------------------------------------------------------
Duration = "5_6"
DataFrame[Duration] = DataFrame[Start_Date_Time_6] - DataFrame[Start_Date_Time_5]
DataFrame.loc[:,[Start_Date_Time_6,Start_Date_Time_5,Duration]]
#------------------------------------------------------------
# Out:
# C:\Users\u291963\AppData\Local\Temp\ipykernel_6148\279200934.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DataFrame[Duration] = DataFrame[Start_Date_Time_2] - DataFrame[Start_Date_Time_1]
# C:\Users\u291963\AppData\Local\Temp\ipykernel_6148\279200934.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DataFrame[Duration] = DataFrame[Start_Date_Time_3] - DataFrame[Start_Date_Time_2]
# C:\Users\u291963\AppData\Local\Temp\ipykernel_6148\279200934.py:10: SettingWithCopyWarning:
# ...

# %%
DataFrame.groupby("حالة المخالفة")[["1_2"]].agg(["mean", "count"])
# Out:
#                                                                          1_2  \
#                                                                         mean
# حالة المخالفة
# تم إرجاعه من قبل أمين اللجنة                                 5 days 04:01:00
# جديد من ممتثل (تم اعادتها إلى مأمور الضبط عبر ا...                       NaT
# في عملية التصويت                                   2 days 01:03:26.666666666
# قيد مراجعة اللجنة                                            0 days 23:16:00
# قيد مراجعة رئيس الهيئة                                       1 days 14:25:30
# مكتمل                                                        1 days 03:35:00
#
#
#                                                    count
# حالة المخالفة
# تم إرجاعه من قبل أمين اللجنة                           1
# جديد من ممتثل (تم اعادتها إلى مأمور الضبط عبر ا...     0
# في عملية التصويت                                       9
# قيد مراجعة اللجنة                                      6
# ...

# %%
DataFrame.groupby("حالة المخالفة")[["2_3"]].agg(["mean", "count"])
# Out:
#                                                                2_3
#                                                               mean count
# حالة المخالفة
# تم إرجاعه من قبل أمين اللجنة                       5 days 04:14:00     1
# جديد من ممتثل (تم اعادتها إلى مأمور الضبط عبر ا...             NaT     0
# في عملية التصويت                                   4 days 08:20:20     9
# قيد مراجعة اللجنة                                  4 days 01:08:50     6
# قيد مراجعة رئيس الهيئة                             5 days 03:21:30     2
# مكتمل                                              4 days 05:09:00     1

# %%
DataFrame.groupby("حالة المخالفة")[["3_4"]].agg(["mean", "count"])
# Out:
#                                                                3_4
#                                                               mean count
# حالة المخالفة
# تم إرجاعه من قبل أمين اللجنة                       2 days 19:25:00     1
# جديد من ممتثل (تم اعادتها إلى مأمور الضبط عبر ا...             NaT     0
# في عملية التصويت                                   2 days 08:57:40     9
# قيد مراجعة اللجنة                                              NaT     0
# قيد مراجعة رئيس الهيئة                             0 days 18:49:00     2
# مكتمل                                              0 days 18:07:00     1

# %%
DataFrame.groupby("حالة المخالفة")[["4_5"]].agg(["mean", "count"])
# Out:
#                                                                4_5
#                                                               mean count
# حالة المخالفة
# تم إرجاعه من قبل أمين اللجنة                                   NaT     0
# جديد من ممتثل (تم اعادتها إلى مأمور الضبط عبر ا...             NaT     0
# في عملية التصويت                                               NaT     0
# قيد مراجعة اللجنة                                              NaT     0
# قيد مراجعة رئيس الهيئة                             3 days 19:50:30     2
# مكتمل                                              1 days 02:29:00     1

# %%
DataFrame.groupby("حالة المخالفة")[["5_6"]].agg(["mean", "count"])
# Out:
#                                                                5_6
#                                                               mean count
# حالة المخالفة
# تم إرجاعه من قبل أمين اللجنة                                   NaT     0
# جديد من ممتثل (تم اعادتها إلى مأمور الضبط عبر ا...             NaT     0
# في عملية التصويت                                               NaT     0
# قيد مراجعة اللجنة                                              NaT     0
# قيد مراجعة رئيس الهيئة                                         NaT     0
# مكتمل                                              0 days 20:29:00     1

# %%
DataFrame.describe().T[["mean"]]
# Out:
#                                                                     mean
# معرف المخالفة في النظام                                      4976.065379
# تاريخ إنشاء المخالفة / الإستلام من بلدي       2025-06-20 10:32:40.921248
# تاريخ الارسال للمخالف                      2025-06-22 10:49:06.315789568
# تاريخ رد المخالف والوصول الى امانة اللجنة  2025-06-26 19:46:03.157894656
# تاريخ الارسال الى اللجنة                   2025-06-27 22:04:09.230769152
# تاريخ الارسال الى معالي رئيس الهيئة                  2025-06-28 03:06:20
# تاريخ قرار معالي رئيس الهيئة                         2025-06-26 12:29:00
# 1_2                                            1 days 18:36:31.578947368
# 2_3                                            4 days 08:56:56.842105263
# 3_4                                            2 days 00:54:32.307692307
# 4_5                                                      2 days 22:03:20
# 5_6                                                      0 days 20:29:00

# %% [markdown]
# ## Visit Vs Violation

# %%
df_violations_13_26_June = df_violations_13_26_June.rename({"رقم زيارة بلدي":"رقم الزيارة"},axis="columns")
df_violations_13_26_June
# Out:
#      رقم الزيارة  معرف المخالفة في النظام  \
# 2919   SWA-52657                     4640
# 2920   SWA-70049                     4641
# 2921   SWA-77018                     4642
# 2922   SWA-70044                     4643
# 2923   SWA-86002                     4644
# ...          ...                      ...
# 3587   SWA-92066                     5309
# 3588   SWA-36253                     5310
# 3589   SWA-90190                     5311
# 3590   SWA-65033                     5312
# 3591   SWA-64001                     5313
#
#                                           حالة المخالفة  \
# 2919  جديد من ممتثل (تم اعادتها إلى مأمور الضبط عبر ...
# 2920  جديد من ممتثل (تم اعادتها إلى مأمور الضبط عبر ...
# 2921  جديد من ممتثل (تم اعادتها إلى مأمور الضبط عبر ...
# 2922  جديد من ممتثل (تم اعادتها إلى مأمور الضبط عبر ...
# 2923  جديد من ممتثل (تم اعادتها إلى مأمور الضبط عبر ...
# ...                                                 ...
# 3587  جديد من ممتثل (تم اعادتها إلى مأمور الضبط عبر ...
# ...

# %%
temp = df_visit_truncated_13_26_June[df_visit_truncated_13_26_June["حالة الزيارة"] == "تم ارسالها للنظر والفصل"]
print(temp.shape)
temp2 = temp.merge(df_violations_13_26_June, how="inner", on="رقم الزيارة")
print(temp2.shape)
# Out:
# (1043, 29)
# (550, 48)

# %%
temp5 = df_visit_truncated_13_26_June.merge(df_violations_13_26_June, how="inner", on="رقم الزيارة")
print(temp5.shape)
# Out:
# (550, 48)

# %%
# Out:
#     رقم الزيارة معرف المخالفة       نوع الزيارة             حالة الزيارة  \
# 0     SWA-77316     V-4170334  زيارة غير مجدولة  تم ارسالها للنظر والفصل
# 1     SWA-90041     V-4147434  زيارة غير مجدولة  تم ارسالها للنظر والفصل
# 2     SWA-88002     V-4105877  زيارة غير مجدولة  تم ارسالها للنظر والفصل
# 3     SWA-77074     V-4115569  زيارة غير مجدولة  تم ارسالها للنظر والفصل
# 4     SWA-77073     V-4115564  زيارة غير مجدولة  تم ارسالها للنظر والفصل
# ..          ...           ...               ...                      ...
# 545   SWA-91092     V-4160628  زيارة غير مجدولة  تم ارسالها للنظر والفصل
# 546   SWA-89127     V-4158556  زيارة غير مجدولة  تم ارسالها للنظر والفصل
# 547   SWA-87260     V-4158603  زيارة غير مجدولة  تم ارسالها للنظر والفصل
# 548   SWA-91079     V-4158222  زيارة غير مجدولة  تم ارسالها للنظر والفصل
# 549   SWA-77261     V-4158780  زيارة غير مجدولة  تم ارسالها للنظر والفصل
#
#     تاريخ انشاء الزيارة تاريخ انهاء الزيارة  \
# 0   2025-06-23 19:12:46 2025-06-23 19:19:06
# ...

# %%
temp2["حالة الزيارة"].value_counts()
# Out:
# حالة الزيارة
# تم ارسالها للنظر والفصل    550
# Name: count, dtype: int64

# %%
temp2.drop_duplicates(subset="رقم الزيارة").shape
# Out:
# (547, 48)

# %%
temp2["رقم الزيارة"].tolist()
# Out:
# ['SWA-77316',
#  'SWA-90041',
#  'SWA-88002',
#  'SWA-77074',
#  'SWA-77073',
#  'SWA-77061',
#  'SWA-88043',
#  'SWA-70067',
#  'SWA-77021',
#  'SWA-77021',
#  'SWA-72093',
#  'SWA-92067',
#  'SWA-70186',
#  'SWA-70076',
#  'SWA-87024',
#  'SWA-89023',
#  'SWA-72101',
#  'SWA-88144',
#  'SWA-86022',
#  'SWA-70159',
#  'SWA-86065',
#  'SWA-86013',
#  'SWA-72045',
#  'SWA-77052',
#  'SWA-87308',
#  'SWA-72025',
#  'SWA-88196',
#  'SWA-77133',
#  'SWA-77136',
#  'SWA-88204',
#  'SWA-89089',
#  'SWA-87101',
#  'SWA-70176',
#  'SWA-70148',
#  'SWA-89005',
#  'SWA-88003',
#  'SWA-70174',
#  'SWA-87078',
#  'SWA-86014',
#  'SWA-89017',
#  'SWA-86028',
#  'SWA-70047',
#  'SWA-77095',
#  'SWA-92006',
#  'SWA-89123',
#  'SWA-88141',
#  'SWA-90123',
#  'SWA-91083',
#  'SWA-91003',
#  'SWA-88187',
#  'SWA-90025',
#  'SWA-89119',
#  'SWA-87224',
#  'SWA-89063',
#  'SWA-90057',
#  'SWA-77324',
#  'SWA-87369',
#  'SWA-89141',
#  'SWA-89177',
#  'SWA-77235',
#  'SWA-91107',
#  'SWA-91077',
# ...

# %%
temp2.sort_values("رقم الزيارة").head(5)
# Out:
#     رقم الزيارة معرف المخالفة       نوع الزيارة             حالة الزيارة  \
# 244   SWA-68073     V-4096350  زيارة غير مجدولة  تم ارسالها للنظر والفصل
# 41    SWA-70047     V-4101834  زيارة غير مجدولة  تم ارسالها للنظر والفصل
# 227   SWA-70049     V-4105752  زيارة غير مجدولة  تم ارسالها للنظر والفصل
# 218   SWA-70051     V-4105869  زيارة غير مجدولة  تم ارسالها للنظر والفصل
# 377   SWA-70053     V-4106155  زيارة غير مجدولة  تم ارسالها للنظر والفصل
# ..          ...           ...               ...                      ...
# 123   SWA-92131     V-4172825  زيارة غير مجدولة  تم ارسالها للنظر والفصل
# 529   SWA-92135     V-4173018  زيارة غير مجدولة  تم ارسالها للنظر والفصل
# 199   SWA-92137     V-4173050  زيارة غير مجدولة  تم ارسالها للنظر والفصل
# 337   SWA-92140     V-4173214  زيارة غير مجدولة  تم ارسالها للنظر والفصل
# 265   SWA-92182     V-4184368  زيارة غير مجدولة  تم ارسالها للنظر والفصل
#
#     تاريخ انشاء الزيارة تاريخ انهاء الزيارة  \
# 244 2025-06-13 16:32:53 2025-06-13 16:39:01
# ...

# %%
print(df_visit_truncated_13_26_June.shape)
print(df_violations_13_26_June.shape)
# Out:
# (2698, 29)
# (673, 20)

# %%
just_violations = set(df_violations_13_26_June["رقم الزيارة"]) - set(df_visit_truncated_13_26_June["رقم الزيارة"]) 
len(just_violations)
# Out:
# 124

# %%
SentButNotinViolation = set(temp["رقم الزيارة"]) - set(df_violations_13_26_June["رقم الزيارة"]) 
len(SentButNotinViolation)
# Out:
# 495

# %%
df_violations_13_26_June.shape[0] - 495 - 124
# Out:
# 54

# %% [markdown]
# ## Violations Volume by Processing Stage

# %%
df_violations_13_26_June.columns
# Out:
# Index(['رقم الزيارة', 'معرف المخالفة في النظام', 'حالة المخالفة',
#        'نوع المخالفة', 'وصف لمخالفة', 'منشأة المأمور', 'مأمور الضبط',
#        'موقع المخالفة', 'تاريخ إنشاء المخالفة / الإستلام من بلدي',
#        'تاريخ الارسال للمخالف', 'تاريخ رد المخالف والوصول الى امانة اللجنة',
#        'تاريخ الارسال الى اللجنة', 'تاريخ الارسال الى معالي رئيس الهيئة',
#        'تاريخ قرار معالي رئيس الهيئة', 'ملاحظات الارجاع من الامين', '1_2',
#        '2_3', '3_4', '4_5', '5_6'],
#       dtype='object')

# %%
df_violations_13_26_June["حالة المخالفة"].value_counts().reset_index()
# Out:
#                                        حالة المخالفة  count
# 0  جديد من ممتثل (تم اعادتها إلى مأمور الضبط عبر ...    654
# 1                                   في عملية التصويت      9
# 2                                  قيد مراجعة اللجنة      6
# 3                             قيد مراجعة رئيس الهيئة      2
# 4                       تم إرجاعه من قبل أمين اللجنة      1
# 5                                              مكتمل      1

# %% [markdown]
# ## Save Files

# %%
violation_path = r"C:\Users\u291963\Desktop\Ammar\Visits & Complaints\01_July\13_26June\violations_13_26_June.xlsx"
visit_path = r"C:\Users\u291963\Desktop\Ammar\Visits & Complaints\01_July\13_26June\visit_13_26_June.xlsx"
CRM_Balady_path = r"C:\Users\u291963\Desktop\Ammar\Visits & Complaints\01_July\13_26June\balady_13_26_June.xlsx"
visit_violation_path=   r"C:\Users\u291963\Desktop\Ammar\Visits & Complaints\01_July\13_26June\visit_violation_merged.xlsx"
temp5.to_excel(visit_violation_path)
df_violations_13_26_June.to_excel(violation_path)
df_visit_truncated_13_26_June.to_excel(visit_path)
df_CRM_fixed_13_26_June.to_excel(CRM_Balady_path)

# %%
temp5["تاريخ انشاء الزيارة"].max()
# Out:
# Timestamp('2025-06-25 15:18:01')

# %% [markdown]
# ## draft

# %%
print(df_CRM_fixed["Complaint_Start_Date"].min())
print(df_CRM_fixed["Complaint_Start_Date"].max())
# Out:
# 2025-05-22 00:00:00
# 2025-06-29 00:00:00

# %%
df_CRM_fixed["حالة البلاغ   لدى محقق الهيئة    مسند"].value_counts(dropna=False).reset_index()
# Out:
#   حالة البلاغ   لدى محقق الهيئة    مسند  count
# 0                                  مسند   2515
# 1                       لدى محقق الهيئة   2438

# %%
2515+2438
# Out:
# 4953

# %%
df_visit_truncated.shape
# Out:
# (19428, 29)

# %%
df_CRM_fixed.shape
# Out:
# (4953, 13)

# %%
df_CRM_fixed.merge(df_visit_truncated, how="inner", on="رقم الزيارة").shape
# Out:
# (2387, 41)

# %% [markdown]
# # CRM Baladi (01_July)
# this before visit (initiator to visit)

# %%
df_CRM = pd.read_excel(r"C:\Users\u291963\Desktop\Ammar\Visits & Complaints\01_July\CRM Baladi_01_June.xlsx")
print(df_CRM.shape[0])
df_CRM_fixed = df_CRM.drop(["المحافظة"], axis="columns")
display(df_CRM.shape)
display(df_CRM_fixed.shape)

# %%
df_CRM_fixed = df_CRM_fixed.drop_duplicates()
display(df_CRM_fixed.shape)

# %%
df_CRM_fixed.columns

# %%
# Convert its type
DataFrame = df_CRM_fixed
Start_Date_Time = "تاريخ تقديم البلاغ"	
Start_Date = "Complaint_Start_Date"
Start_Time = "Complaint_Start_Time"

DataFrame[Start_Date_Time] = pd.to_datetime(DataFrame[Start_Date_Time])
# Extract the columns

## Date
DataFrame[Start_Date] = DataFrame[Start_Date_Time].dt.date
DataFrame[Start_Date] = pd.to_datetime(DataFrame[Start_Date], format='%Y-%m-%d')

## Time
DataFrame[Start_Time]  = DataFrame[Start_Date_Time].dt.time
DataFrame[Start_Time]  = pd.to_datetime(DataFrame[Start_Time] ,format='%H:%M:%S').dt.time

# check
DataFrame.loc[:,[Start_Date_Time, Start_Date, Start_Time]]

# %%
df_CRM_fixed

# %%
df_eastern = df_CRM[df_CRM["المنطقة"] == "الشرقية"]
df_eastern

# %%
df_Riadh= df_CRM[df_CRM["المنطقة"] == "الرياض"]
# Assuming your DataFrame is named 'df'
counts = df_Riadh['رقم الزيارة'].value_counts()
duplicated_counts = counts[counts > 1]

# duplicated_counts now contains the counts of duplicated values in 'col1'
# To display it as a DataFrame:
duplicated_df = duplicated_counts.reset_index()
duplicated_df.columns = ['رقم الزيارة', 'count']
display(duplicated_df.sort_values("count"))

# %%
# Assuming your DataFrame is named 'df'
counts = df_eastern['رقم الزيارة'].value_counts()
duplicated_counts = counts[counts > 1]

# duplicated_counts now contains the counts of duplicated values in 'col1'
# To display it as a DataFrame:
duplicated_df = duplicated_counts.reset_index()
duplicated_df.columns = ['رقم الزيارة', 'count']
print(duplicated_df)
